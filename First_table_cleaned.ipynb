# %% [markdown]
# <a href="https://colab.research.google.com/github/TKhahahah/Text_Analytics/blob/main/First_table_cleaned.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mini Project 2: Data Analytics and Modeling

# %% [markdown]
# <img src="https://datarundown.com/wp-content/uploads/2023/05/Model-Data-Analytics.jpg" width="400px">

# %% [markdown]
# ชื่อกลุ่ม: ...
#
# รายชื่อสมาชิก การแบ่งงาน และสัดส่วนในการทำงาน:
# 1. ...
# 2. ...
# 3. ...
# 4. ...
#
# กำหนดส่ง: ศุกร์ 24 ตุลาคม 2568
#
# รายงานในชั้นเรียน: เสาร์ 25 ตุลาคม 2568
#
# ** NOTE **
# * อย่าลืมบันทึกงานที่ทำในโน้ตบุ๊คนี้เป็นประจำขณะทำงาน มิเช่นนั้นงานที่ทำอยู่อาจสูญหายได้
# * **เริ่มทำแต่เนิ่น ๆ อย่ารอที่จะทำก่อนส่ง เพราะจะทำไม่เสร็จ เนื่องจากปัญหามากมายที่จะเกิดขึ้นระหว่างการทำงาน และอาจารย์ไม่รับปรึกษาในคืนก่อนส่ง**
# ----------------------

# %% [markdown]
# ### เลือกชุดข้อมูล 1 ชุดจากข้อมูลที่กำหนดให้ต่อไปนี้
# * <b>MovieLens 1M Data Set<b>
#     * ข้อมูลชุดนี้มีข้อมูลเกี่ยวกับ movies, users, และ how they rate the movies
#     * สามารถดูรายละเอียดได้ที่ http://grouplens.org/datasets/movielens/
#     * Download the 1 million ratings data set from https://grouplens.org/datasets/movielens/1m/
#     * Merge all of the data into a single Pandas DataFrame. See
#         * https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html
#
# * <b>Walmart_Sales_Forecast<b>
#     * สามารถดูรายละเอียดได้ที่ https://github.com/Asikpalysik/Walmart_Sales_Forecast/tree/main
#     * ข้อมูลประกอบด้วยไฟล์ features.csv, stores.csv และ ข้อมูลยอดขาย (train.csv และ test.csv)
#     * ให้ใช้ข้อมูลจากทุกไฟล์ทุกอย่างประกอบกันในการวิเคราะห์
#
# * <b>NYC Taxi Trips<b>
#     * ข้อมูลทริปของแท็กซี่ในเมืองนิวยอร์กจาก https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page
#     * ข้อมูลเก็บโดย The NYC Taxi and Limousine Commission (TLC) ประกอบด้วย pick-up and drop-off dates/times, pick-up and drop-off locations, trip distances, itemized fares, rate types, payment types, and driver-reported passenger counts
#     * นอกจากไฟล์ข้อมูลทริปของแท็กซี่แล้ว ยังมีข้อมูลเกี่ยวกับ zone ของพื้นที่ที่ให้บริการ และคำอธิบายข้อมูลในส่วนล่างสุดของหน้าเดียวกัน
#     * ให้ศึกษาข้อมูลการเดินทางของแท็กซี่เหลืองหรือแท็กซี่เขียวในช่วงหนึ่ง (เช่น 1 เดือน หรือ 1 ปีที่ผ่านมา เป็นต้น)
#     * ตัวอย่างการอ่านไฟล์ parquet
#     ```python
#     # install this module to read .parquet files
#     !pip install pyarrow
#     import pyarrow.parquet as pq
#     trips = pq.read_table('yellow_tripdata_2023-09.parquet')
#     trips = trips.to_pandas()
#     trips
#     ```
#
# ----------------------------------

# %% [markdown]
# ### ศึกษาข้อมูลที่เลือกใช้ แล้วทำการ
# * Tell story about data อธิบายลักษณะของข้อมูล ทำความเข้าใจเกี่ยวกับข้อมูลชุดนี้ ด้วยสถิติ และนำเสนอด้วยแผนภาพ แผนภูมิ หรือกราฟต่าง ๆ
# * ตั้ง<span style="color:red">*ปัญหาหรือคำถามเชิงองค์กรหรือธุรกิจ*</span>ที่กลุ่มท่านสนใจเกี่ยวกับข้อมูลนี้ แล้วทำการคาดการณ์ (conjectures) เกี่ยวกับ<span style="color:red">*ปัญหาหรือคำถาม*</span>ที่ได้ตั้งไว้อย่างน้อย 3 ข้อ แล้วสนับสนุนหรือปฏิเสธข้อคาดการณ์ด้วยการวิเคราะห์ข้อมูลหรือด้วย data visualization
#     * ปัญหาที่สนใจมีความสำคัญอย่างไร?
#     * ข้อคาดการณ์ของท่านจะนำไปสู่การแก้ไขปัญหาหรือตอบคำถามอย่างไร?
# * สร้างตัวแบบทำนายโดยใช้ข้อมูลที่เลือกในการตอบปัญหาหรือคำถาม
#     * prepare data
#     * feature engineering
#     * partition data (consider class if any)
#     * handle imbalance data
#     * build model
#       * hyperparameter tuning
#     * test model

# %% [markdown]
# #### ปัญหา/คำถามที่สนใจคืออะไร
# ...
#
# #### ปัญหา/คำถามที่สนใจมีความสำคัญอย่างไร?
# ...
#
# #### ข้อคาดการณ์ของท่านจะนำไปสู่การแก้ไขปัญหาหรือตอบคำถาม
# 1. ...
# 2. ...
# 3. ...
# 4. (Optional)
# 5. (Optional)

# %% [markdown]
# ## Data Loading

# %%
# Load data✅

# Merge data if necessary✅
import pandas as pd
import polars as pl

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pyarrow
import pyarrow.parquet as pq
# Out:
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (18.1.0)

# %%
oct_ytaxi = pl.read_parquet('/content/drive/MyDrive/DTW2/yellow_tripdata_2024-10.parquet')
oct_ytaxi
# Out:
# shape: (3_833_771, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ Airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i32      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ i64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ f64       │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ f64       ┆           │
# │          ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2        ┆ 2024-10-0 ┆ 2024-10-0 ┆ 1         ┆ … ┆ 1.0       ┆ 24.9      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:30:44  ┆ 00:48:26  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-10-0 ┆ 2024-10-0 ┆ 1         ┆ … ┆ 1.0       ┆ 23.0      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:12:20  ┆ 00:25:25  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-10-0 ┆ 2024-10-0 ┆ 1         ┆ … ┆ 1.0       ┆ 22.2      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:04:46  ┆ 00:13:52  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-10-0 ┆ 2024-10-0 ┆ 1         ┆ … ┆ 1.0       ┆ 21.2      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:12:10  ┆ 00:23:01  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-10-0 ┆ 2024-10-0 ┆ 1         ┆ … ┆ 1.0       ┆ 8.0       ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:30:22  ┆ 00:30:39  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …        ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2        ┆ 2024-10-3 ┆ 2024-11-0 ┆ null      ┆ … ┆ 1.0       ┆ 25.36     ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:49:01  ┆ 00:04:31  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-10-3 ┆ 2024-10-3 ┆ null      ┆ … ┆ 1.0       ┆ 43.05     ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:35:15  ┆ 23:52:50  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-10-3 ┆ 2024-11-0 ┆ null      ┆ … ┆ 1.0       ┆ 53.62     ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:30:43  ┆ 00:08:12  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-10-3 ┆ 2024-10-3 ┆ null      ┆ … ┆ 1.0       ┆ 20.84     ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:00:00  ┆ 23:06:00  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-10-3 ┆ 2024-10-3 ┆ null      ┆ … ┆ 1.0       ┆ 29.96     ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:18:00  ┆ 23:51:00  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
nov_ytaxi = pl.read_parquet('/content/drive/MyDrive/DTW2/yellow_tripdata_2024-11.parquet')
nov_ytaxi
# Out:
# shape: (3_646_369, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ Airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i32      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ i64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ f64       │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ f64       ┆           │
# │          ┆ μs]       ┆ μs]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2        ┆ 2024-11-0 ┆ 2024-11-0 ┆ 1         ┆ … ┆ -1.0      ┆ -17.8     ┆ -2.5      ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:46:24  ┆ 00:57:17  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-11-0 ┆ 2024-11-0 ┆ 1         ┆ … ┆ 1.0       ┆ 17.8      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:46:24  ┆ 00:57:17  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-11-0 ┆ 2024-11-0 ┆ 1         ┆ … ┆ 1.0       ┆ 275.0     ┆ 0.0       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:37:36  ┆ 01:28:36  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-11-0 ┆ 2024-11-0 ┆ 2         ┆ … ┆ 1.0       ┆ 16.0      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:12:55  ┆ 00:22:17  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-11-0 ┆ 2024-11-0 ┆ 1         ┆ … ┆ 1.0       ┆ 12.5      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:54:45  ┆ 00:59:47  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …        ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2        ┆ 2024-11-3 ┆ 2024-11-3 ┆ null      ┆ … ┆ 1.0       ┆ 5.0       ┆ null      ┆ null      │
# │          ┆ 0         ┆ 0         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:11:15  ┆ 23:19:33  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-11-3 ┆ 2024-12-0 ┆ null      ┆ … ┆ 1.0       ┆ 89.03     ┆ null      ┆ null      │
# │          ┆ 0         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:49:30  ┆ 00:27:39  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-11-3 ┆ 2024-12-0 ┆ null      ┆ … ┆ 1.0       ┆ 22.71     ┆ null      ┆ null      │
# │          ┆ 0         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:31:46  ┆ 00:04:32  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-11-3 ┆ 2024-11-3 ┆ null      ┆ … ┆ 1.0       ┆ 14.76     ┆ null      ┆ null      │
# │          ┆ 0         ┆ 0         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:41:21  ┆ 23:53:20  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-11-3 ┆ 2024-11-3 ┆ null      ┆ … ┆ 1.0       ┆ 1.0       ┆ null      ┆ null      │
# │          ┆ 0         ┆ 0         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:21:52  ┆ 23:31:11  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
dec_ytaxi = pl.read_parquet('/content/drive/MyDrive/DTW2/yellow_tripdata_2024-12.parquet')
dec_ytaxi
# Out:
# shape: (3_668_371, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ Airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i32      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ i64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ f64       │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ f64       ┆           │
# │          ┆ μs]       ┆ μs]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2        ┆ 2024-12-0 ┆ 2024-12-0 ┆ 1         ┆ … ┆ 1.0       ┆ 51.97     ┆ 0.0       ┆ 1.75      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:12:27  ┆ 00:31:12  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-11-3 ┆ 2024-12-0 ┆ 1         ┆ … ┆ 1.0       ┆ 50.76     ┆ 2.5       ┆ 0.0       │
# │          ┆ 0         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:56:04  ┆ 00:28:15  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-12-0 ┆ 2024-12-0 ┆ 4         ┆ … ┆ 1.0       ┆ 82.69     ┆ 2.5       ┆ 1.75      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:50:35  ┆ 01:24:46  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-12-0 ┆ 2024-12-0 ┆ 3         ┆ … ┆ 1.0       ┆ 24.72     ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:18:16  ┆ 00:33:16  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-12-0 ┆ 2024-12-0 ┆ 1         ┆ … ┆ 1.0       ┆ 36.8      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:56:13  ┆ 01:18:25  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …        ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2        ┆ 2024-12-3 ┆ 2024-12-3 ┆ null      ┆ … ┆ 1.0       ┆ -2.63     ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:32:00  ┆ 23:56:00  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-12-3 ┆ 2024-12-3 ┆ null      ┆ … ┆ 1.0       ┆ -0.18     ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:05:00  ┆ 23:18:00  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-12-3 ┆ 2024-12-3 ┆ null      ┆ … ┆ 1.0       ┆ 11.15     ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:03:16  ┆ 23:28:35  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-12-3 ┆ 2024-12-3 ┆ null      ┆ … ┆ 1.0       ┆ 28.57     ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:15:33  ┆ 23:36:29  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-12-3 ┆ 2024-12-3 ┆ null      ┆ … ┆ 1.0       ┆ 6.17      ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:04:36  ┆ 23:33:34  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
zone_location = pd.read_csv('/content/drive/MyDrive/DTW2/taxi_zone_lookup.csv')
zone_location
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                      NaN          NaN
# 264         265            NaN           Outside of NYC          NaN
#
# [265 rows x 4 columns]

# %%
import geopandas as gpd

gdf = gpd.read_file("/content/drive/MyDrive/DTW2/taxi_zones")
print(gdf.columns)
# Out:
# Index(['OBJECTID', 'Shape_Leng', 'Shape_Area', 'zone', 'LocationID', 'borough',
#        'geometry'],
#       dtype='object')

# %%
merged_gdf = gdf.merge(zone_location, on='LocationID', how='left')
print(merged_gdf.head())
# Out:
#    OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0         1    0.116357    0.000782           Newark Airport           1
# 1         2    0.433470    0.004866              Jamaica Bay           2
# 2         3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3         4    0.043567    0.000112            Alphabet City           4
# 4         5    0.092146    0.000498            Arden Heights           5
#
#          borough                                           geometry  \
# 0            EWR  POLYGON ((933100.918 192536.086, 933091.011 19...
# 1         Queens  MULTIPOLYGON (((1033269.244 172126.008, 103343...
# 2          Bronx  POLYGON ((1026308.77 256767.698, 1026495.593 2...
# 3      Manhattan  POLYGON ((992073.467 203714.076, 992068.667 20...
# 4  Staten Island  POLYGON ((935843.31 144283.336, 936046.565 144...
#
#          Borough                     Zone service_zone
# 0            EWR           Newark Airport          EWR
# 1         Queens              Jamaica Bay    Boro Zone
# 2          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3      Manhattan            Alphabet City  Yellow Zone
# 4  Staten Island            Arden Heights    Boro Zone

# %% [markdown]
# ###รวมข้อมูล 3 เดือน และ drop คอลัมน์ที่ไม่ได้ใช้ออก

# %%
# Convert datetime columns in oct_ytaxi to microseconds precision
oct_ytaxi = oct_ytaxi.with_columns(
    pl.col("tpep_pickup_datetime").cast(pl.Datetime("us")),
    pl.col("tpep_dropoff_datetime").cast(pl.Datetime("us"))
)

df_quarters4_ytaxi = pl.concat([oct_ytaxi, nov_ytaxi, dec_ytaxi]) #รวมหัวมูลแบบแนวตั้งเนื่องจากมีคอลัมน์เหมือนกัน

df_quarters4_ytaxi
# Out:
# shape: (11_148_511, 19)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ Airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ ee        │
# │ i32      ┆ me        ┆ ime       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ i64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ f64       │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆ f64       ┆           ┆ f64       ┆           │
# │          ┆ μs]       ┆ μs]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2        ┆ 2024-10-0 ┆ 2024-10-0 ┆ 1         ┆ … ┆ 1.0       ┆ 24.9      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:30:44  ┆ 00:48:26  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-10-0 ┆ 2024-10-0 ┆ 1         ┆ … ┆ 1.0       ┆ 23.0      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:12:20  ┆ 00:25:25  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-10-0 ┆ 2024-10-0 ┆ 1         ┆ … ┆ 1.0       ┆ 22.2      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:04:46  ┆ 00:13:52  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-10-0 ┆ 2024-10-0 ┆ 1         ┆ … ┆ 1.0       ┆ 21.2      ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:12:10  ┆ 00:23:01  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-10-0 ┆ 2024-10-0 ┆ 1         ┆ … ┆ 1.0       ┆ 8.0       ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:30:22  ┆ 00:30:39  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …        ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2        ┆ 2024-12-3 ┆ 2024-12-3 ┆ null      ┆ … ┆ 1.0       ┆ -2.63     ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:32:00  ┆ 23:56:00  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-12-3 ┆ 2024-12-3 ┆ null      ┆ … ┆ 1.0       ┆ -0.18     ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:05:00  ┆ 23:18:00  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-12-3 ┆ 2024-12-3 ┆ null      ┆ … ┆ 1.0       ┆ 11.15     ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:03:16  ┆ 23:28:35  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-12-3 ┆ 2024-12-3 ┆ null      ┆ … ┆ 1.0       ┆ 28.57     ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:15:33  ┆ 23:36:29  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-12-3 ┆ 2024-12-3 ┆ null      ┆ … ┆ 1.0       ┆ 6.17      ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:04:36  ┆ 23:33:34  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
df_quarters4_ytaxi.columns
# Out:
# ['VendorID',
#  'tpep_pickup_datetime',
#  'tpep_dropoff_datetime',
#  'passenger_count',
#  'trip_distance',
#  'RatecodeID',
#  'store_and_fwd_flag',
#  'PULocationID',
#  'DOLocationID',
#  'payment_type',
#  'fare_amount',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'improvement_surcharge',
#  'total_amount',
#  'congestion_surcharge',
#  'Airport_fee']

# %%
sl_quarters4_ytaxi = df_quarters4_ytaxi.drop(['store_and_fwd_flag','payment_type','extra','mta_tax','improvement_surcharge','total_amount'])
sl_quarters4_ytaxi
# Out:
# shape: (11_148_511, 13)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ VendorID ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ tip_amoun ┆ tolls_amo ┆ congestio ┆ Airport_f │
# │ ---      ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ t         ┆ unt       ┆ n_surchar ┆ ee        │
# │ i32      ┆ me        ┆ ime       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ge        ┆ ---       │
# │          ┆ ---       ┆ ---       ┆ i64       ┆   ┆ f64       ┆ f64       ┆ ---       ┆ f64       │
# │          ┆ datetime[ ┆ datetime[ ┆           ┆   ┆           ┆           ┆ f64       ┆           │
# │          ┆ μs]       ┆ μs]       ┆           ┆   ┆           ┆           ┆           ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2        ┆ 2024-10-0 ┆ 2024-10-0 ┆ 1         ┆ … ┆ 1.5       ┆ 0.0       ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:30:44  ┆ 00:48:26  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-10-0 ┆ 2024-10-0 ┆ 1         ┆ … ┆ 3.8       ┆ 0.0       ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:12:20  ┆ 00:25:25  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-10-0 ┆ 2024-10-0 ┆ 1         ┆ … ┆ 3.7       ┆ 0.0       ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:04:46  ┆ 00:13:52  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-10-0 ┆ 2024-10-0 ┆ 1         ┆ … ┆ 2.0       ┆ 0.0       ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:12:10  ┆ 00:23:01  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-10-0 ┆ 2024-10-0 ┆ 1         ┆ … ┆ 0.0       ┆ 0.0       ┆ 2.5       ┆ 0.0       │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 00:30:22  ┆ 00:30:39  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …        ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2        ┆ 2024-12-3 ┆ 2024-12-3 ┆ null      ┆ … ┆ 0.0       ┆ 0.0       ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:32:00  ┆ 23:56:00  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-12-3 ┆ 2024-12-3 ┆ null      ┆ … ┆ 0.0       ┆ 0.0       ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:05:00  ┆ 23:18:00  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-12-3 ┆ 2024-12-3 ┆ null      ┆ … ┆ 5.19      ┆ 0.0       ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:03:16  ┆ 23:28:35  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1        ┆ 2024-12-3 ┆ 2024-12-3 ┆ null      ┆ … ┆ 0.0       ┆ 0.0       ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:15:33  ┆ 23:36:29  ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 2        ┆ 2024-12-3 ┆ 2024-12-3 ┆ null      ┆ … ┆ 0.0       ┆ 0.0       ┆ null      ┆ null      │
# │          ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆           ┆           │
# │          ┆ 23:04:36  ┆ 23:33:34  ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
df_quarters4_ytaxi = sl_quarters4_ytaxi.to_pandas()

# %%
df_quarters4_ytaxi
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2024-10-01 00:30:44   2024-10-01 00:48:26
# 1                1  2024-10-01 00:12:20   2024-10-01 00:25:25
# 2                1  2024-10-01 00:04:46   2024-10-01 00:13:52
# 3                1  2024-10-01 00:12:10   2024-10-01 00:23:01
# 4                1  2024-10-01 00:30:22   2024-10-01 00:30:39
# ...            ...                  ...                   ...
# 11148506         2  2024-12-31 23:32:00   2024-12-31 23:56:00
# 11148507         2  2024-12-31 23:05:00   2024-12-31 23:18:00
# 11148508         2  2024-12-31 23:03:16   2024-12-31 23:28:35
# 11148509         1  2024-12-31 23:15:33   2024-12-31 23:36:29
# 11148510         2  2024-12-31 23:04:36   2024-12-31 23:33:34
#
#           passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0                     1.0           3.00         1.0           162
# 1                     1.0           2.20         1.0            48
# 2                     1.0           2.70         1.0           142
# 3                     1.0           3.10         1.0           233
# 4                     1.0           0.00         1.0           262
# ...                   ...            ...         ...           ...
# 11148506              NaN          10.71         NaN            16
# 11148507              NaN           4.56         NaN           252
# 11148508              NaN           3.94         NaN           181
# 11148509              NaN           4.20         NaN           165
# 11148510              NaN           5.76         NaN           225
#
#           DOLocationID  fare_amount  tip_amount  tolls_amount  \
# 0                  246        18.40        1.50           0.0
# 1                  236        14.20        3.80           0.0
# 2                   24        13.50        3.70           0.0
# 3                   75        14.20        2.00           0.0
# 4                  262         3.00        0.00           0.0
# ...                ...          ...         ...           ...
# 11148506             7        -4.13        0.00           0.0
# 11148507            16        -1.68        0.00           0.0
# 11148508           255         4.46        5.19           0.0
# 11148509            61        27.07        0.00           0.0
# 11148510           114         2.17        0.00           0.0
#
#           congestion_surcharge  Airport_fee
# 0                          2.5          0.0
# 1                          2.5          0.0
# 2                          2.5          0.0
# 3                          2.5          0.0
# 4                          2.5          0.0
# ...                        ...          ...
# 11148506                   NaN          NaN
# 11148507                   NaN          NaN
# 11148508                   NaN          NaN
# 11148509                   NaN          NaN
# 11148510                   NaN          NaN
#
# [11148511 rows x 13 columns]

# %% [markdown]
# ## Data Preparation

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Explore variables and check data quality✅

# Handle missing values✅, outliers✅, and noises✅

# Perform feature engineering (optional)✅

# %%
df_quarters4_ytaxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11148511 entries, 0 to 11148510
# Data columns (total 13 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   PULocationID           int32
#  7   DOLocationID           int32
#  8   fare_amount            float64
#  9   tip_amount             float64
#  10  tolls_amount           float64
#  11  congestion_surcharge   float64
#  12  Airport_fee            float64
# dtypes: datetime64[us](2), float64(8), int32(3)
# memory usage: 978.1 MB

# %%
for col in df_quarters4_ytaxi.select_dtypes(include=['float64']).columns:
    df_quarters4_ytaxi[col] = df_quarters4_ytaxi[col].astype(np.float32)

for col in df_quarters4_ytaxi.select_dtypes(include=['int64']).columns:
    df_quarters4_ytaxi[col] = df_quarters4_ytaxi[col].astype(np.int32)

# %%
df_quarters4_ytaxi.dtypes
# Out:
# VendorID                          int32
# tpep_pickup_datetime     datetime64[us]
# tpep_dropoff_datetime    datetime64[us]
# passenger_count                 float32
# trip_distance                   float32
# RatecodeID                      float32
# PULocationID                      int32
# DOLocationID                      int32
# fare_amount                     float32
# tip_amount                      float32
# tolls_amount                    float32
# congestion_surcharge            float32
# Airport_fee                     float32
# dtype: object

# %% [markdown]
# ### Handle missing and duplicates

# %%
# Check missing value
df_quarters4_ytaxi.isna().sum()
# Out:
# VendorID                       0
# tpep_pickup_datetime           0
# tpep_dropoff_datetime          0
# passenger_count          1093860
# trip_distance                  0
# RatecodeID               1093860
# PULocationID                   0
# DOLocationID                   0
# fare_amount                    0
# tip_amount                     0
# tolls_amount                   0
# congestion_surcharge     1093860
# Airport_fee              1093860
# dtype: int64

# %%
# Check duplicate row
print("Number of duplicate rows:")
print(df_quarters4_ytaxi.duplicated().sum())
# Out:
# Number of duplicate rows:
# 103

# %%
#remove duplicates
cl_quarters4_ytaxi = df_quarters4_ytaxi.drop_duplicates()
cl_quarters4_ytaxi
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2024-10-01 00:30:44   2024-10-01 00:48:26
# 1                1  2024-10-01 00:12:20   2024-10-01 00:25:25
# 2                1  2024-10-01 00:04:46   2024-10-01 00:13:52
# 3                1  2024-10-01 00:12:10   2024-10-01 00:23:01
# 4                1  2024-10-01 00:30:22   2024-10-01 00:30:39
# ...            ...                  ...                   ...
# 11148506         2  2024-12-31 23:32:00   2024-12-31 23:56:00
# 11148507         2  2024-12-31 23:05:00   2024-12-31 23:18:00
# 11148508         2  2024-12-31 23:03:16   2024-12-31 23:28:35
# 11148509         1  2024-12-31 23:15:33   2024-12-31 23:36:29
# 11148510         2  2024-12-31 23:04:36   2024-12-31 23:33:34
#
#           passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0                     1.0           3.00         1.0           162
# 1                     1.0           2.20         1.0            48
# 2                     1.0           2.70         1.0           142
# 3                     1.0           3.10         1.0           233
# 4                     1.0           0.00         1.0           262
# ...                   ...            ...         ...           ...
# 11148506              NaN          10.71         NaN            16
# 11148507              NaN           4.56         NaN           252
# 11148508              NaN           3.94         NaN           181
# 11148509              NaN           4.20         NaN           165
# 11148510              NaN           5.76         NaN           225
#
#           DOLocationID  fare_amount  tip_amount  tolls_amount  \
# 0                  246        18.40        1.50           0.0
# 1                  236        14.20        3.80           0.0
# 2                   24        13.50        3.70           0.0
# 3                   75        14.20        2.00           0.0
# 4                  262         3.00        0.00           0.0
# ...                ...          ...         ...           ...
# 11148506             7        -4.13        0.00           0.0
# 11148507            16        -1.68        0.00           0.0
# 11148508           255         4.46        5.19           0.0
# 11148509            61        27.07        0.00           0.0
# 11148510           114         2.17        0.00           0.0
#
#           congestion_surcharge  Airport_fee
# 0                          2.5          0.0
# 1                          2.5          0.0
# 2                          2.5          0.0
# 3                          2.5          0.0
# 4                          2.5          0.0
# ...                        ...          ...
# 11148506                   NaN          NaN
# 11148507                   NaN          NaN
# 11148508                   NaN          NaN
# 11148509                   NaN          NaN
# 11148510                   NaN          NaN
#
# [11148408 rows x 13 columns]

# %%
#Handle missing value
cl_quarters4_ytaxi.isna().sum()
# Out:
# VendorID                       0
# tpep_pickup_datetime           0
# tpep_dropoff_datetime          0
# passenger_count          1093860
# trip_distance                  0
# RatecodeID               1093860
# PULocationID                   0
# DOLocationID                   0
# fare_amount                    0
# tip_amount                     0
# tolls_amount                   0
# congestion_surcharge     1093860
# Airport_fee              1093860
# dtype: int64

# %%
import pandas as pd

# Columns to fill using MODE
mode_cols = ['passenger_count','RatecodeID','congestion_surcharge','Airport_fee']

# Fill missing values by MODE for selected columns
for col in mode_cols:
    mode_value = cl_quarters4_ytaxi[col].mode()[0]
    cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].fillna(mode_value)

print(cl_quarters4_ytaxi)
# Out:
# /tmp/ipython-input-438503265.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].fillna(mode_value)
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2024-10-01 00:30:44   2024-10-01 00:48:26
# 1                1  2024-10-01 00:12:20   2024-10-01 00:25:25
# 2                1  2024-10-01 00:04:46   2024-10-01 00:13:52
# 3                1  2024-10-01 00:12:10   2024-10-01 00:23:01
# 4                1  2024-10-01 00:30:22   2024-10-01 00:30:39
# ...            ...                  ...                   ...
# 11148506         2  2024-12-31 23:32:00   2024-12-31 23:56:00
# 11148507         2  2024-12-31 23:05:00   2024-12-31 23:18:00
# 11148508         2  2024-12-31 23:03:16   2024-12-31 23:28:35
# 11148509         1  2024-12-31 23:15:33   2024-12-31 23:36:29
# 11148510         2  2024-12-31 23:04:36   2024-12-31 23:33:34
#
#           passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0                     1.0           3.00         1.0           162
# 1                     1.0           2.20         1.0            48
# 2                     1.0           2.70         1.0           142
# 3                     1.0           3.10         1.0           233
# 4                     1.0           0.00         1.0           262
# ...                   ...            ...         ...           ...
# 11148506              1.0          10.71         1.0            16
# 11148507              1.0           4.56         1.0           252
# 11148508              1.0           3.94         1.0           181
# 11148509              1.0           4.20         1.0           165
# 11148510              1.0           5.76         1.0           225
#
#           DOLocationID  fare_amount  tip_amount  tolls_amount  \
# 0                  246        18.40        1.50           0.0
# 1                  236        14.20        3.80           0.0
# 2                   24        13.50        3.70           0.0
# 3                   75        14.20        2.00           0.0
# 4                  262         3.00        0.00           0.0
# ...                ...          ...         ...           ...
# 11148506             7        -4.13        0.00           0.0
# 11148507            16        -1.68        0.00           0.0
# 11148508           255         4.46        5.19           0.0
# 11148509            61        27.07        0.00           0.0
# 11148510           114         2.17        0.00           0.0
#
#           congestion_surcharge  Airport_fee
# 0                          2.5          0.0
# 1                          2.5          0.0
# 2                          2.5          0.0
# 3                          2.5          0.0
# 4                          2.5          0.0
# ...                        ...          ...
# 11148506                   2.5          0.0
# 11148507                   2.5          0.0
# 11148508                   2.5          0.0
# 11148509                   2.5          0.0
# 11148510                   2.5          0.0
#
# [11148408 rows x 13 columns]

# %%
cl_quarters4_ytaxi.isna().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# PULocationID             0
# DOLocationID             0
# fare_amount              0
# tip_amount               0
# tolls_amount             0
# congestion_surcharge     0
# Airport_fee              0
# dtype: int64

# %%
cl_quarters4_ytaxi
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2024-10-01 00:30:44   2024-10-01 00:48:26
# 1                1  2024-10-01 00:12:20   2024-10-01 00:25:25
# 2                1  2024-10-01 00:04:46   2024-10-01 00:13:52
# 3                1  2024-10-01 00:12:10   2024-10-01 00:23:01
# 4                1  2024-10-01 00:30:22   2024-10-01 00:30:39
# ...            ...                  ...                   ...
# 11148506         2  2024-12-31 23:32:00   2024-12-31 23:56:00
# 11148507         2  2024-12-31 23:05:00   2024-12-31 23:18:00
# 11148508         2  2024-12-31 23:03:16   2024-12-31 23:28:35
# 11148509         1  2024-12-31 23:15:33   2024-12-31 23:36:29
# 11148510         2  2024-12-31 23:04:36   2024-12-31 23:33:34
#
#           passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0                     1.0           3.00         1.0           162
# 1                     1.0           2.20         1.0            48
# 2                     1.0           2.70         1.0           142
# 3                     1.0           3.10         1.0           233
# 4                     1.0           0.00         1.0           262
# ...                   ...            ...         ...           ...
# 11148506              1.0          10.71         1.0            16
# 11148507              1.0           4.56         1.0           252
# 11148508              1.0           3.94         1.0           181
# 11148509              1.0           4.20         1.0           165
# 11148510              1.0           5.76         1.0           225
#
#           DOLocationID  fare_amount  tip_amount  tolls_amount  \
# 0                  246        18.40        1.50           0.0
# 1                  236        14.20        3.80           0.0
# 2                   24        13.50        3.70           0.0
# 3                   75        14.20        2.00           0.0
# 4                  262         3.00        0.00           0.0
# ...                ...          ...         ...           ...
# 11148506             7        -4.13        0.00           0.0
# 11148507            16        -1.68        0.00           0.0
# 11148508           255         4.46        5.19           0.0
# 11148509            61        27.07        0.00           0.0
# 11148510           114         2.17        0.00           0.0
#
#           congestion_surcharge  Airport_fee
# 0                          2.5          0.0
# 1                          2.5          0.0
# 2                          2.5          0.0
# 3                          2.5          0.0
# 4                          2.5          0.0
# ...                        ...          ...
# 11148506                   2.5          0.0
# 11148507                   2.5          0.0
# 11148508                   2.5          0.0
# 11148509                   2.5          0.0
# 11148510                   2.5          0.0
#
# [11148408 rows x 13 columns]

# %% [markdown]
# ### Handle outliers

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# ตัวอย่างคอลัมน์
cols = ['passenger_count', 'trip_distance', 'fare_amount', 'tip_amount','tolls_amount','congestion_surcharge','Airport_fee']
for col in cols:
    Q1 = cl_quarters4_ytaxi[col].quantile(0.25)
    Q3 = cl_quarters4_ytaxi[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    # Use pandas filtering
    outliers = cl_quarters4_ytaxi[(cl_quarters4_ytaxi[col] < lower) | (cl_quarters4_ytaxi[col] > upper)]
    print(f"🔹 {col}: พบ {outliers.shape[0]} outliers") # Use .shape[0] for Pandas DataFrame row count

    # วาด boxplot ดูการกระจาย
    sns.boxplot(x=cl_quarters4_ytaxi[col])
    plt.title(f"Outliers in {col}")
    plt.show()
# Out:
# 🔹 passenger_count: พบ 2307877 outliers
# 🔹 trip_distance: พบ 1435364 outliers
# 🔹 fare_amount: พบ 1096919 outliers
# 🔹 tip_amount: พบ 632663 outliers
# 🔹 tolls_amount: พบ 851735 outliers
# 🔹 congestion_surcharge: พบ 928528 outliers
# 🔹 Airport_fee: พบ 853019 outliers

# %% [markdown]
# Identify Columns: It first defines a list of numerical columns (cols_to_cap) where outliers will be addressed.
# Calculate IQR: For each column in the list:
# It calculates the first quartile (Q1), which is the 25th percentile of the data.
# It calculates the third quartile (Q3), which is the 75th percentile of the data.
# The Interquartile Range (IQR) is then calculated as the difference between Q3 and Q1 (IQR = Q3 - Q1). The IQR represents the middle 50% of the data.
# Determine Bounds:
# The lower bound for outlier detection is calculated as Q1 - 1.5 * IQR.
# The upper bound is calculated as Q3 + 1.5 * IQR.
# Any data point below the lower bound or above the upper bound is considered an outlier based on this method.
# Capping:
# The code then iterates through the specified columns and applies the capping logic.
# For each value in a column, it checks if the value is less than the lower_bound. If it is, the value is replaced (capped) with the lower_bound.
# If the value is greater than the upper_bound, it is replaced (capped) with the upper_bound.
# If the value falls within the calculated bounds, it remains unchanged.
# This method effectively limits the influence of extreme values by bringing them closer to the main body of the data distribution, rather than removing them entirely. This can be useful when you want to keep all data points but reduce the impact of outliers on your analysis or model.

# %%
# Handle outliers by capping
cols_to_cap = ['passenger_count', 'trip_distance', 'fare_amount',
               'tip_amount', 'tolls_amount', 'congestion_surcharge', 'Airport_fee']

for col in cols_to_cap:
    if col == 'passenger_count':
        # สำหรับ passenger_count ให้จำกัดค่าระหว่าง 1 ถึง 6 โดยตรง
        cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].clip(lower=1, upper=6)
    else:
        # คำนวณ IQR สำหรับคอลัมน์อื่น
        Q1 = cl_quarters4_ytaxi[col].quantile(0.25)
        Q3 = cl_quarters4_ytaxi[col].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Cap ค่าที่เกินช่วง IQR
        cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].clip(lower=lower_bound, upper=upper_bound)

        # แสดงสรุปสั้น ๆ ว่ามีการ cap เท่าไร
        n_capped_lower = (cl_quarters4_ytaxi[col] < lower_bound).sum()
        n_capped_upper = (cl_quarters4_ytaxi[col] > upper_bound).sum()
        print(f"{col}: capped {n_capped_lower + n_capped_upper} values "
              f"(lower={lower_bound:.2f}, upper={upper_bound:.2f})")

print("\n✅ Outliers have been capped successfully.")
# Out:
# /tmp/ipython-input-3592399055.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].clip(lower=1, upper=6)
# /tmp/ipython-input-3592399055.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].clip(lower=lower_bound, upper=upper_bound)
# trip_distance: capped 0 values (lower=-2.45, upper=6.75)
# /tmp/ipython-input-3592399055.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].clip(lower=lower_bound, upper=upper_bound)
# fare_amount: capped 0 values (lower=-11.70, upper=44.30)
# /tmp/ipython-input-3592399055.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].clip(lower=lower_bound, upper=upper_bound)
# tip_amount: capped 0 values (lower=-6.60, upper=11.00)
# /tmp/ipython-input-3592399055.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].clip(lower=lower_bound, upper=upper_bound)
# tolls_amount: capped 0 values (lower=0.00, upper=0.00)
# /tmp/ipython-input-3592399055.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].clip(lower=lower_bound, upper=upper_bound)
# congestion_surcharge: capped 0 values (lower=2.50, upper=2.50)
# Airport_fee: capped 0 values (lower=0.00, upper=0.00)
#
# ✅ Outliers have been capped successfully.
# /tmp/ipython-input-3592399055.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].clip(lower=lower_bound, upper=upper_bound)

# %%
# ตรวจสอบผลลัพธ์หลัง capping
cl_quarters4_ytaxi[cols_to_cap].describe()
# Out:
#        passenger_count  trip_distance   fare_amount    tip_amount  \
# count     1.114841e+07   1.114841e+07  1.114841e+07  1.114841e+07
# mean      1.308600e+00   2.503453e+00  1.772678e+01  3.111261e+00
# std       7.204711e-01   2.067451e+00  1.217712e+01  3.043648e+00
# min       1.000000e+00   0.000000e+00 -1.170000e+01 -6.600000e+00
# 25%       1.000000e+00   1.000000e+00  9.300000e+00  0.000000e+00
# 50%       1.000000e+00   1.710000e+00  1.420000e+01  2.660000e+00
# 75%       1.000000e+00   3.300000e+00  2.330000e+01  4.400000e+00
# max       6.000000e+00   6.750000e+00  4.430000e+01  1.100000e+01
#
#        tolls_amount  congestion_surcharge  Airport_fee
# count    11148408.0          1.114841e+07   11148408.0
# mean            0.0          2.500000e+00          0.0
# std             0.0          3.533366e-01          0.0
# min             0.0          2.500000e+00          0.0
# 25%             0.0          2.500000e+00          0.0
# 50%             0.0          2.500000e+00          0.0
# 75%             0.0          2.500000e+00          0.0
# max             0.0          2.500000e+00          0.0

# %%
# # Handle outliers by capping
# cols_to_cap = ['passenger_count', 'trip_distance', 'fare_amount', 'tip_amount','tolls_amount','congestion_surcharge','Airport_fee']

# for col in cols_to_cap:
#     Q1 = cl_quarters4_ytaxi[col].quantile(0.25)
#     Q3 = cl_quarters4_ytaxi[col].quantile(0.75)
#     IQR = Q3 - Q1

#     lower_bound = Q1 - 1.5 * IQR
#     upper_bound = Q3 + 1.5 * IQR

#     # Cap the values
#     cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].clip(lower=lower_bound, upper=upper_bound)

# print("Outliers have been capped.")
# Out:
# /tmp/ipython-input-2334567318.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].clip(lower=lower_bound, upper=upper_bound)
# /tmp/ipython-input-2334567318.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].clip(lower=lower_bound, upper=upper_bound)
# /tmp/ipython-input-2334567318.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].clip(lower=lower_bound, upper=upper_bound)
# /tmp/ipython-input-2334567318.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].clip(lower=lower_bound, upper=upper_bound)
# /tmp/ipython-input-2334567318.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].clip(lower=lower_bound, upper=upper_bound)
# /tmp/ipython-input-2334567318.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].clip(lower=lower_bound, upper=upper_bound)
# Outliers have been capped.
# /tmp/ipython-input-2334567318.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi[col] = cl_quarters4_ytaxi[col].clip(lower=lower_bound, upper=upper_bound)

# %%
# Check outliers after capping by looking at box plots
import matplotlib.pyplot as plt
import seaborn as sns

# Select numerical columns for box plots
numerical_cols = ['passenger_count', 'trip_distance', 'fare_amount', 'tip_amount','tolls_amount','congestion_surcharge','Airport_fee']

# Create box plots for each numerical column
plt.figure(figsize=(15, 15)) # Increased figure size for better visualization
for i, col in enumerate(numerical_cols):
    plt.subplot(3, 3, i + 1) # Changed to 3, 3 to accommodate 7 plots
    sns.boxplot(y=cl_quarters4_ytaxi[col])
    plt.title(f'Box plot of {col} after capping')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Handle noise

# %%
#distance>=0 and fare_mount >= 0
cl_quarters4_ytaxi = cl_quarters4_ytaxi [(cl_quarters4_ytaxi ['trip_distance'] >= 0) & (cl_quarters4_ytaxi ['fare_amount'] >= 0)]

# %%
cl_quarters4_ytaxi = cl_quarters4_ytaxi[
    (cl_quarters4_ytaxi['trip_distance'] > 0)
    & (cl_quarters4_ytaxi['fare_amount'] > 0)
    & (cl_quarters4_ytaxi['passenger_count'] >= 1) & (cl_quarters4_ytaxi['passenger_count'] < 7)
    & (cl_quarters4_ytaxi['PULocationID'] >= 1) & (cl_quarters4_ytaxi['PULocationID'] <= 263)
    & (cl_quarters4_ytaxi['DOLocationID'] >= 1) & (cl_quarters4_ytaxi['DOLocationID'] <= 263)
    & (cl_quarters4_ytaxi['duration'] > 1) & (cl_quarters4_ytaxi['duration'] <= 180)
]

# %%
cl_quarters4_ytaxi
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2024-10-01 00:30:44   2024-10-01 00:48:26
# 1                1  2024-10-01 00:12:20   2024-10-01 00:25:25
# 2                1  2024-10-01 00:04:46   2024-10-01 00:13:52
# 3                1  2024-10-01 00:12:10   2024-10-01 00:23:01
# 5                2  2024-10-01 00:31:20   2024-10-01 00:36:00
# ...            ...                  ...                   ...
# 11148501         1  2024-12-31 23:21:36   2024-12-31 23:32:10
# 11148504         1  2024-12-31 23:14:53   2024-12-31 23:35:13
# 11148508         2  2024-12-31 23:03:16   2024-12-31 23:28:35
# 11148509         1  2024-12-31 23:15:33   2024-12-31 23:36:29
# 11148510         2  2024-12-31 23:04:36   2024-12-31 23:33:34
#
#           passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0                     1.0           3.00         1.0           162
# 1                     1.0           2.20         1.0            48
# 2                     1.0           2.70         1.0           142
# 3                     1.0           3.10         1.0           233
# 5                     2.0           0.97         1.0           137
# ...                   ...            ...         ...           ...
# 11148501              1.0           1.60         1.0           188
# 11148504              1.0           2.90         1.0           145
# 11148508              1.0           3.94         1.0           181
# 11148509              1.0           4.20         1.0           165
# 11148510              1.0           5.76         1.0           225
#
#           DOLocationID  fare_amount  tip_amount  tolls_amount  \
# 0                  246    18.400000        1.50           0.0
# 1                  236    14.200000        3.80           0.0
# 2                   24    13.500000        3.70           0.0
# 3                   75    14.200000        2.00           0.0
# 5                  137     7.200000        2.44           0.0
# ...                ...          ...         ...           ...
# 11148501            61    13.280000        0.00           0.0
# 11148504           164    21.940001        0.00           0.0
# 11148508           255     4.460000        5.19           0.0
# 11148509            61    27.070000        0.00           0.0
# 11148510           114     2.170000        0.00           0.0
#
#           congestion_surcharge  Airport_fee       date  time  weekday  \
# 0                          2.5          0.0 2024-10-01     0  Tuesday
# 1                          2.5          0.0 2024-10-01     0  Tuesday
# 2                          2.5          0.0 2024-10-01     0  Tuesday
# 3                          2.5          0.0 2024-10-01     0  Tuesday
# 5                          2.5          0.0 2024-10-01     0  Tuesday
# ...                        ...          ...        ...   ...      ...
# 11148501                   2.5          0.0 2024-12-31    23  Tuesday
# 11148504                   2.5          0.0 2024-12-31    23  Tuesday
# 11148508                   2.5          0.0 2024-12-31    23  Tuesday
# 11148509                   2.5          0.0 2024-12-31    23  Tuesday
# 11148510                   2.5          0.0 2024-12-31    23  Tuesday
#
#            duration
# 0         17.700000
# 1         13.083333
# 2          9.100000
# 3         10.850000
# 5          4.666667
# ...             ...
# 11148501  10.566667
# 11148504  20.333333
# 11148508  25.316667
# 11148509  20.933333
# 11148510  28.966667
#
# [10571492 rows x 17 columns]

# %% [markdown]
# ### Feature enginering

# %%
import numpy as np

# %%
import pandas as pd
import numpy as np

# %%
# Feature engineering
# extract day and time, the calculate the duration of the trip
cl_quarters4_ytaxi['tpep_pickup_datetime'] = pd.to_datetime(cl_quarters4_ytaxi['tpep_pickup_datetime'])
cl_quarters4_ytaxi['tpep_dropoff_datetime'] = pd.to_datetime(cl_quarters4_ytaxi['tpep_dropoff_datetime'])
cl_quarters4_ytaxi['date'] = cl_quarters4_ytaxi['tpep_pickup_datetime'].dt.normalize()
cl_quarters4_ytaxi['time'] = cl_quarters4_ytaxi['tpep_pickup_datetime'].dt.hour
cl_quarters4_ytaxi['weekday'] = cl_quarters4_ytaxi['date'].dt.day_name()
cl_quarters4_ytaxi['duration'] = cl_quarters4_ytaxi['tpep_dropoff_datetime'] - cl_quarters4_ytaxi['tpep_pickup_datetime']
cl_quarters4_ytaxi['duration'] = cl_quarters4_ytaxi['duration'] / np.timedelta64(1, 'm')
# Out:
# /tmp/ipython-input-3573154859.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi['tpep_pickup_datetime'] = pd.to_datetime(cl_quarters4_ytaxi['tpep_pickup_datetime'])
# /tmp/ipython-input-3573154859.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi['tpep_dropoff_datetime'] = pd.to_datetime(cl_quarters4_ytaxi['tpep_dropoff_datetime'])
# /tmp/ipython-input-3573154859.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi['date'] = cl_quarters4_ytaxi['tpep_pickup_datetime'].dt.normalize()
# /tmp/ipython-input-3573154859.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi['time'] = cl_quarters4_ytaxi['tpep_pickup_datetime'].dt.hour
# /tmp/ipython-input-3573154859.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi['weekday'] = cl_quarters4_ytaxi['date'].dt.day_name()
# /tmp/ipython-input-3573154859.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi['duration'] = cl_quarters4_ytaxi['tpep_dropoff_datetime'] - cl_quarters4_ytaxi['tpep_pickup_datetime']
# /tmp/ipython-input-3573154859.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_quarters4_ytaxi['duration'] = cl_quarters4_ytaxi['duration'] / np.timedelta64(1, 'm')

# %%
cl_quarters4_ytaxi
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2024-10-01 00:30:44   2024-10-01 00:48:26
# 1                1  2024-10-01 00:12:20   2024-10-01 00:25:25
# 2                1  2024-10-01 00:04:46   2024-10-01 00:13:52
# 3                1  2024-10-01 00:12:10   2024-10-01 00:23:01
# 4                1  2024-10-01 00:30:22   2024-10-01 00:30:39
# ...            ...                  ...                   ...
# 11148506         2  2024-12-31 23:32:00   2024-12-31 23:56:00
# 11148507         2  2024-12-31 23:05:00   2024-12-31 23:18:00
# 11148508         2  2024-12-31 23:03:16   2024-12-31 23:28:35
# 11148509         1  2024-12-31 23:15:33   2024-12-31 23:36:29
# 11148510         2  2024-12-31 23:04:36   2024-12-31 23:33:34
#
#           passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0                     1.0           3.00         1.0           162
# 1                     1.0           2.20         1.0            48
# 2                     1.0           2.70         1.0           142
# 3                     1.0           3.10         1.0           233
# 4                     1.0           0.00         1.0           262
# ...                   ...            ...         ...           ...
# 11148506              1.0           6.75         1.0            16
# 11148507              1.0           4.56         1.0           252
# 11148508              1.0           3.94         1.0           181
# 11148509              1.0           4.20         1.0           165
# 11148510              1.0           5.76         1.0           225
#
#           DOLocationID  fare_amount  tip_amount  tolls_amount  \
# 0                  246        18.40        1.50           0.0
# 1                  236        14.20        3.80           0.0
# 2                   24        13.50        3.70           0.0
# 3                   75        14.20        2.00           0.0
# 4                  262         3.00        0.00           0.0
# ...                ...          ...         ...           ...
# 11148506             7        -4.13        0.00           0.0
# 11148507            16        -1.68        0.00           0.0
# 11148508           255         4.46        5.19           0.0
# 11148509            61        27.07        0.00           0.0
# 11148510           114         2.17        0.00           0.0
#
#           congestion_surcharge  Airport_fee       date  time  weekday  \
# 0                          2.5          0.0 2024-10-01     0  Tuesday
# 1                          2.5          0.0 2024-10-01     0  Tuesday
# 2                          2.5          0.0 2024-10-01     0  Tuesday
# 3                          2.5          0.0 2024-10-01     0  Tuesday
# 4                          2.5          0.0 2024-10-01     0  Tuesday
# ...                        ...          ...        ...   ...      ...
# 11148506                   2.5          0.0 2024-12-31    23  Tuesday
# 11148507                   2.5          0.0 2024-12-31    23  Tuesday
# 11148508                   2.5          0.0 2024-12-31    23  Tuesday
# 11148509                   2.5          0.0 2024-12-31    23  Tuesday
# 11148510                   2.5          0.0 2024-12-31    23  Tuesday
#
#            duration
# 0         17.700000
# 1         13.083333
# 2          9.100000
# 3         10.850000
# 4          0.283333
# ...             ...
# 11148506  24.000000
# 11148507  13.000000
# 11148508  25.316667
# 11148509  20.933333
# 11148510  28.966667
#
# [11148408 rows x 17 columns]

# %%
cl_quarters4_ytaxi
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2024-10-01 00:30:44   2024-10-01 00:48:26
# 1                1  2024-10-01 00:12:20   2024-10-01 00:25:25
# 2                1  2024-10-01 00:04:46   2024-10-01 00:13:52
# 3                1  2024-10-01 00:12:10   2024-10-01 00:23:01
# 5                2  2024-10-01 00:31:20   2024-10-01 00:36:00
# ...            ...                  ...                   ...
# 11148501         1  2024-12-31 23:21:36   2024-12-31 23:32:10
# 11148504         1  2024-12-31 23:14:53   2024-12-31 23:35:13
# 11148508         2  2024-12-31 23:03:16   2024-12-31 23:28:35
# 11148509         1  2024-12-31 23:15:33   2024-12-31 23:36:29
# 11148510         2  2024-12-31 23:04:36   2024-12-31 23:33:34
#
#           passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0                     1.0           3.00         1.0           162
# 1                     1.0           2.20         1.0            48
# 2                     1.0           2.70         1.0           142
# 3                     1.0           3.10         1.0           233
# 5                     2.0           0.97         1.0           137
# ...                   ...            ...         ...           ...
# 11148501              1.0           1.60         1.0           188
# 11148504              1.0           2.90         1.0           145
# 11148508              1.0           3.94         1.0           181
# 11148509              1.0           4.20         1.0           165
# 11148510              1.0           5.76         1.0           225
#
#           DOLocationID  fare_amount  tip_amount  tolls_amount  \
# 0                  246    18.400000        1.50           0.0
# 1                  236    14.200000        3.80           0.0
# 2                   24    13.500000        3.70           0.0
# 3                   75    14.200000        2.00           0.0
# 5                  137     7.200000        2.44           0.0
# ...                ...          ...         ...           ...
# 11148501            61    13.280000        0.00           0.0
# 11148504           164    21.940001        0.00           0.0
# 11148508           255     4.460000        5.19           0.0
# 11148509            61    27.070000        0.00           0.0
# 11148510           114     2.170000        0.00           0.0
#
#           congestion_surcharge  Airport_fee       date  time  weekday  \
# 0                          2.5          0.0 2024-10-01     0  Tuesday
# 1                          2.5          0.0 2024-10-01     0  Tuesday
# 2                          2.5          0.0 2024-10-01     0  Tuesday
# 3                          2.5          0.0 2024-10-01     0  Tuesday
# 5                          2.5          0.0 2024-10-01     0  Tuesday
# ...                        ...          ...        ...   ...      ...
# 11148501                   2.5          0.0 2024-12-31    23  Tuesday
# 11148504                   2.5          0.0 2024-12-31    23  Tuesday
# 11148508                   2.5          0.0 2024-12-31    23  Tuesday
# 11148509                   2.5          0.0 2024-12-31    23  Tuesday
# 11148510                   2.5          0.0 2024-12-31    23  Tuesday
#
#            duration
# 0         17.700000
# 1         13.083333
# 2          9.100000
# 3         10.850000
# 5          4.666667
# ...             ...
# 11148501  10.566667
# 11148504  20.333333
# 11148508  25.316667
# 11148509  20.933333
# 11148510  28.966667
#
# [10571492 rows x 17 columns]

# %%
# Save the cleaned DataFrame to a file (e.g., Parquet)
output_path = '/content/drive/MyDrive/DTW2/cleaned_1.parquet'
cl_quarters4_ytaxi.to_parquet(output_path)

print(f"Cleaned data saved to: {output_path}")
# Out:
# Cleaned data saved to: /content/drive/MyDrive/DTW2/cleaned_1.parquet

# %% [markdown]
# ## Explore Data

# %%
# Descriptive statistics

# Data visualization
# Target variable analysis: examine how each feature correlates with or impacts the target/interested variable

# %% [markdown]
# ## Data Modeling

# %%
# Partition data

# Handle imbalance data (optional)

# Model selection and tuning

# Evaluate models

# %% [markdown]
# #### สรุปผลที่ได้
# ...

# %% [markdown]
# -----------------
# # เสร็จแล้ววววว 🥳
#
# สิ่งที่ต้องแนบส่ง:
# * Notebook File (ตัวอย่าง "filename.ipynb") หรือ Link to Google Colab / GitHub ซึ่งมีผลลัพธ์จากการรันโค้ดแสดงทั้งหมด
# * Slides สำหรับการนำเสนอ **10** นาที ซึ่งประกอบไปด้วย
#     * Data Description: อธิบายข้อมูลที่ใช้
#     * Data Preparation: การเตรียมข้อมูลก่อนวิเคราะห์
#     * Motivation: ปัญหาหรือคำถามที่ตั้ง ทำไมถึงสนใจที่จะทำงานในเรื่องนี้
#     * Communicating Results (with figure, table, etc.): ผลที่ได้จากการศึกษา โดยระบุแนวทางที่ใช้ที่ทำให้เกิดผลลัพธ์ดังกล่าวด้วย
#         โดยไม่ต้องนำเสนอ source code ผลประกอบด้วย 2 ส่วนสำคัญ จาก
#         * Conjectures >= 3 ข้อ
#         * Machine learning models
#     * Conclusion: สรุปผลที่ได้จากการวิเคราะห์ข้อมูล
# ** Note: แต่ละกลุ่มส่งแต่ละไฟล์ครั้งเดียว **
# ---------------------
