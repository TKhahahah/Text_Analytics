# %% [markdown]
# <a href="https://colab.research.google.com/github/TKhahahah/Text_Analytics/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pyarrow
# !pip install squarify
# Out:
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (18.1.0)
# Requirement already satisfied: squarify in /usr/local/lib/python3.12/dist-packages (0.4.4)

# %%
import pyarrow.parquet as pq
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick
import squarify
import matplotlib.cm as cm

# %%
taxi_data = pq.read_table('/content/drive/MyDrive/DTW2/cleaned_final.parquet')
taxi_data = taxi_data.to_pandas()
taxi_data
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2024-10-01 00:30:44   2024-10-01 00:48:26
# 1                1  2024-10-01 00:12:20   2024-10-01 00:25:25
# 2                1  2024-10-01 00:04:46   2024-10-01 00:13:52
# 3                1  2024-10-01 00:12:10   2024-10-01 00:23:01
# 5                2  2024-10-01 00:31:20   2024-10-01 00:36:00
# ...            ...                  ...                   ...
# 11148500         1  2024-12-31 23:42:33   2024-12-31 23:53:54
# 11148501         1  2024-12-31 23:21:36   2024-12-31 23:32:10
# 11148504         1  2024-12-31 23:14:53   2024-12-31 23:35:13
# 11148508         2  2024-12-31 23:03:16   2024-12-31 23:28:35
# 11148509         1  2024-12-31 23:15:33   2024-12-31 23:36:29
#
#           passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0                     1.0           3.00         1.0           162
# 1                     1.0           2.20         1.0            48
# 2                     1.0           2.70         1.0           142
# 3                     1.0           3.10         1.0           233
# 5                     2.0           0.97         1.0           137
# ...                   ...            ...         ...           ...
# 11148500              1.0           1.70         1.0            61
# 11148501              1.0           1.60         1.0           188
# 11148504              1.0           2.90         1.0           145
# 11148508              1.0           3.94         1.0           181
# 11148509              1.0           4.20         1.0           165
#
#           DOLocationID  fare_amount  tip_amount  tolls_amount  \
# 0                  246    18.400000        1.50          0.00
# 1                  236    14.200000        3.80          0.00
# 2                   24    13.500000        3.70          0.00
# 3                   75    14.200000        2.00          0.00
# 5                  137     7.200000        2.44          0.00
# ...                ...          ...         ...           ...
# 11148500            71    11.400000        0.00          0.00
# 11148501            61    13.280000        0.00          0.00
# 11148504           164    21.940001        0.00          6.94
# 11148508           255     4.460000        5.19          0.00
# 11148509            61    27.070000        0.00          0.00
#
#           congestion_surcharge  Airport_fee       date  time  weekday  \
# 0                          2.5          0.0 2024-10-01     0  Tuesday
# 1                          2.5          0.0 2024-10-01     0  Tuesday
# 2                          2.5          0.0 2024-10-01     0  Tuesday
# 3                          2.5          0.0 2024-10-01     0  Tuesday
# 5                          2.5          0.0 2024-10-01     0  Tuesday
# ...                        ...          ...        ...   ...      ...
# 11148500                   2.5          0.0 2024-12-31    23  Tuesday
# 11148501                   2.5          0.0 2024-12-31    23  Tuesday
# 11148504                   2.5          0.0 2024-12-31    23  Tuesday
# 11148508                   2.5          0.0 2024-12-31    23  Tuesday
# 11148509                   2.5          0.0 2024-12-31    23  Tuesday
#
#            duration
# 0         17.700001
# 1         13.083333
# 2          9.100000
# 3         10.850000
# 5          4.666667
# ...             ...
# 11148500  11.350000
# 11148501  10.566667
# 11148504  20.333334
# 11148508  25.316668
# 11148509  20.933332
#
# [10348975 rows x 17 columns]

# %%
zone_location = pd.read_csv('/content/drive/MyDrive/DTW2/taxi_zone_lookup.csv')
zone_location
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                      NaN          NaN
# 264         265            NaN           Outside of NYC          NaN
#
# [265 rows x 4 columns]

# %%
import geopandas as gpd

gdf = gpd.read_file("/content/drive/MyDrive/DTW2/taxi_zones")
print(gdf.columns)
# Out:
# Index(['OBJECTID', 'Shape_Leng', 'Shape_Area', 'zone', 'LocationID', 'borough',
#        'geometry'],
#       dtype='object')

# %%
merged_gdf = gdf.merge(zone_location, on='LocationID', how='left')
print(merged_gdf.head())
# Out:
#    OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0         1    0.116357    0.000782           Newark Airport           1
# 1         2    0.433470    0.004866              Jamaica Bay           2
# 2         3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3         4    0.043567    0.000112            Alphabet City           4
# 4         5    0.092146    0.000498            Arden Heights           5
#
#          borough                                           geometry  \
# 0            EWR  POLYGON ((933100.918 192536.086, 933091.011 19...
# 1         Queens  MULTIPOLYGON (((1033269.244 172126.008, 103343...
# 2          Bronx  POLYGON ((1026308.77 256767.698, 1026495.593 2...
# 3      Manhattan  POLYGON ((992073.467 203714.076, 992068.667 20...
# 4  Staten Island  POLYGON ((935843.31 144283.336, 936046.565 144...
#
#          Borough                     Zone service_zone
# 0            EWR           Newark Airport          EWR
# 1         Queens              Jamaica Bay    Boro Zone
# 2          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3      Manhattan            Alphabet City  Yellow Zone
# 4  Staten Island            Arden Heights    Boro Zone

# %%
#create 2nd table to merging pl_df_pandas and merge_gdf
map_data = taxi_data.merge(merged_gdf, left_on='PULocationID', right_on='LocationID', how='left')
map_data
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2024-10-01 00:30:44   2024-10-01 00:48:26
# 1                1  2024-10-01 00:12:20   2024-10-01 00:25:25
# 2                1  2024-10-01 00:04:46   2024-10-01 00:13:52
# 3                1  2024-10-01 00:12:10   2024-10-01 00:23:01
# 4                2  2024-10-01 00:31:20   2024-10-01 00:36:00
# ...            ...                  ...                   ...
# 10349847         1  2024-12-31 23:42:33   2024-12-31 23:53:54
# 10349848         1  2024-12-31 23:21:36   2024-12-31 23:32:10
# 10349849         1  2024-12-31 23:14:53   2024-12-31 23:35:13
# 10349850         2  2024-12-31 23:03:16   2024-12-31 23:28:35
# 10349851         1  2024-12-31 23:15:33   2024-12-31 23:36:29
#
#           passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0                     1.0           3.00         1.0           162
# 1                     1.0           2.20         1.0            48
# 2                     1.0           2.70         1.0           142
# 3                     1.0           3.10         1.0           233
# 4                     2.0           0.97         1.0           137
# ...                   ...            ...         ...           ...
# 10349847              1.0           1.70         1.0            61
# 10349848              1.0           1.60         1.0           188
# 10349849              1.0           2.90         1.0           145
# 10349850              1.0           3.94         1.0           181
# 10349851              1.0           4.20         1.0           165
#
#           DOLocationID  fare_amount  tip_amount  ...  OBJECTID  Shape_Leng  \
# 0                  246    18.400000        1.50  ...     162.0    0.035270
# 1                  236    14.200000        3.80  ...      48.0    0.043747
# 2                   24    13.500000        3.70  ...     142.0    0.038176
# 3                   75    14.200000        2.00  ...     233.0    0.048036
# 4                  137     7.200000        2.44  ...     137.0    0.046108
# ...                ...          ...         ...  ...       ...         ...
# 10349847            71    11.400000        0.00  ...      61.0    0.117311
# 10349848            61    13.280000        0.00  ...     188.0    0.097798
# 10349849           164    21.940001        0.00  ...     145.0    0.114314
# 10349850           255     4.460000        5.19  ...     181.0    0.089537
# 10349851            61    27.070000        0.00  ...     165.0    0.088608
#
#           Shape_Area                            zone  LocationID    borough  \
# 0           0.000048                    Midtown East       162.0  Manhattan
# 1           0.000094                    Clinton East        48.0  Manhattan
# 2           0.000076             Lincoln Square East       142.0  Manhattan
# 3           0.000116             UN/Turtle Bay South       233.0  Manhattan
# 4           0.000116                        Kips Bay       137.0  Manhattan
# ...              ...                             ...         ...        ...
# 10349847    0.000511             Crown Heights North        61.0   Brooklyn
# 10349848    0.000313       Prospect-Lefferts Gardens       188.0   Brooklyn
# 10349849    0.000347  Long Island City/Hunters Point       145.0     Queens
# 10349850    0.000307                      Park Slope       181.0   Brooklyn
# 10349851    0.000354                         Midwood       165.0   Brooklyn
#
#                                                    geometry    Borough  \
# 0         POLYGON ((992224.354 214415.293, 992096.999 21...  Manhattan
# 1         POLYGON ((986694.313 214463.846, 986568.184 21...  Manhattan
# 2         POLYGON ((989380.305 218980.247, 989359.803 21...  Manhattan
# 3         MULTIPOLYGON (((993816.792 213230.43, 993857.4...  Manhattan
# 4         POLYGON ((991954.728 209026.462, 991949.076 20...  Manhattan
# ...                                                     ...        ...
# 10349847  POLYGON ((1003897.089 188278.65, 1003939.593 1...   Brooklyn
# 10349848  POLYGON ((996098.526 181302.644, 996121.518 18...   Brooklyn
# 10349849  POLYGON ((999916.846 213275.139, 1000066.513 2...     Queens
# 10349850  POLYGON ((990954.947 181851.707, 990815.59 181...   Brooklyn
# 10349851  POLYGON ((995312.051 168409.655, 995365.558 16...   Brooklyn
#
#                                     Zone  service_zone
# 0                           Midtown East   Yellow Zone
# 1                           Clinton East   Yellow Zone
# 2                    Lincoln Square East   Yellow Zone
# 3                    UN/Turtle Bay South   Yellow Zone
# 4                               Kips Bay   Yellow Zone
# ...                                  ...           ...
# 10349847             Crown Heights North     Boro Zone
# 10349848       Prospect-Lefferts Gardens     Boro Zone
# 10349849  Long Island City/Hunters Point     Boro Zone
# 10349850                      Park Slope     Boro Zone
# 10349851                         Midwood     Boro Zone
#
# [10349852 rows x 27 columns]

# %%
map_data.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'PULocationID',
#        'DOLocationID', 'fare_amount', 'tip_amount', 'tolls_amount',
#        'congestion_surcharge', 'Airport_fee', 'date', 'time', 'weekday',
#        'duration', 'OBJECTID', 'Shape_Leng', 'Shape_Area', 'zone',
#        'LocationID', 'borough', 'geometry', 'Borough', 'Zone', 'service_zone'],
#       dtype='object')

# %%
map_data.isnull().sum()
# Out:
# VendorID                  0
# tpep_pickup_datetime      0
# tpep_dropoff_datetime     0
# passenger_count           0
# trip_distance             0
# RatecodeID                0
# PULocationID              0
# DOLocationID              0
# fare_amount               0
# tip_amount                0
# tolls_amount              0
# congestion_surcharge      0
# Airport_fee               0
# date                      0
# time                      0
# weekday                   0
# duration                  0
# OBJECTID                 63
# Shape_Leng               63
# Shape_Area               63
# zone                     63
# LocationID               63
# borough                  63
# geometry                 63
# Borough                  63
# Zone                     63
# service_zone             63
# dtype: int64

# %%
import geopandas as gpd
import pandas as pd
import numpy as np

def clean_geo_missing(gdf: gpd.GeoDataFrame) -> gpd.GeoDataFrame:
    """
    ตรวจและจัดการ missing values สำหรับข้อมูลเชิงพื้นที่ (GeoDataFrame)
    - drop geometry ที่หาย
    - fillna สำหรับ attribute (string, numeric)
    - แสดงรายงานก่อนและหลังทำความสะอาด
    """

    print("🔍 ตรวจสอบ missing values ก่อนทำความสะอาด:")
    print(gdf.isna().sum())
    print("-" * 60)

    # 1️⃣ ลบ geometry ที่หาย (เพราะ plot/map ไม่ได้)
    if 'geometry' in gdf.columns:
        missing_geo = gdf['geometry'].isna().sum()
        if missing_geo > 0:
            print(f"🗑️ ลบ geometry ที่หาย {missing_geo} แถว")
            gdf = gdf.dropna(subset=['geometry'])

    # 2️⃣ จัดการคอลัมน์อื่น ๆ
    for col in gdf.columns:
        if col == 'geometry':
            continue  # geometry จัดการแล้ว

        if gdf[col].isna().sum() == 0:
            continue  # ไม่มี missing

        # ✅ ถ้าเป็นตัวเลข — ใช้ median (ถ้าไม่ได้ ใช้ mean)
        if pd.api.types.is_numeric_dtype(gdf[col]):
            median_val = gdf[col].median()
            if np.isnan(median_val):
                mean_val = gdf[col].mean()
                gdf[col] = gdf[col].fillna(mean_val)
                print(f"🔹 {col}: เติมค่า missing ด้วย mean = {mean_val:.2f}")
            else:
                gdf[col] = gdf[col].fillna(median_val)
                print(f"🔹 {col}: เติมค่า missing ด้วย median = {median_val:.2f}")

        # ✅ ถ้าเป็นข้อความ — เติมด้วย 'Unknown'
        elif gdf[col].dtype == 'object' or pd.api.types.is_categorical_dtype(gdf[col]):
            gdf[col] = gdf[col].fillna('Unknown')
            print(f"🔹 {col}: เติมค่า missing ด้วย 'Unknown'")

    # 3️⃣ แสดงรายงานหลังทำ
    print("\n✅ ตรวจสอบอีกครั้งหลังทำความสะอาด:")
    print(gdf.isna().sum())

    print("-" * 60)
    print(f"✅ ข้อมูลสะอาดแล้ว ({len(gdf)} แถว)")
    return gdf

# %%
map_data = clean_geo_missing(map_data)
# Out:
# 🔍 ตรวจสอบ missing values ก่อนทำความสะอาด:
# VendorID                  0
# tpep_pickup_datetime      0
# tpep_dropoff_datetime     0
# passenger_count           0
# trip_distance             0
# RatecodeID                0
# PULocationID              0
# DOLocationID              0
# fare_amount               0
# tip_amount                0
# tolls_amount              0
# congestion_surcharge      0
# Airport_fee               0
# date                      0
# time                      0
# weekday                   0
# duration                  0
# OBJECTID                 63
# Shape_Leng               63
# Shape_Area               63
# zone                     63
# LocationID               63
# borough                  63
# geometry                 63
# Borough                  63
# Zone                     63
# service_zone             63
# dtype: int64
# ------------------------------------------------------------
# 🗑️ ลบ geometry ที่หาย 63 แถว
#
# ✅ ตรวจสอบอีกครั้งหลังทำความสะอาด:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# PULocationID             0
# DOLocationID             0
# fare_amount              0
# tip_amount               0
# tolls_amount             0
# congestion_surcharge     0
# Airport_fee              0
# date                     0
# time                     0
# weekday                  0
# duration                 0
# OBJECTID                 0
# Shape_Leng               0
# Shape_Area               0
# zone                     0
# LocationID               0
# borough                  0
# geometry                 0
# Borough                  0
# Zone                     0
# service_zone             0
# dtype: int64
# ------------------------------------------------------------
# ✅ ข้อมูลสะอาดแล้ว (10349789 แถว)

# %% [markdown]
# #Data Loading

# %%
map_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10349789 entries, 0 to 10349851
# Data columns (total 27 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float32
#  4   trip_distance          float32
#  5   RatecodeID             float32
#  6   PULocationID           int32
#  7   DOLocationID           int32
#  8   fare_amount            float32
#  9   tip_amount             float32
#  10  tolls_amount           float32
#  11  congestion_surcharge   float32
#  12  Airport_fee            float32
#  13  date                   datetime64[us]
#  14  time                   int32
#  15  weekday                object
#  16  duration               float32
#  17  OBJECTID               float64
#  18  Shape_Leng             float64
#  19  Shape_Area             float64
#  20  zone                   object
#  21  LocationID             float64
#  22  borough                object
#  23  geometry               geometry
#  24  Borough                object
#  25  Zone                   object
#  26  service_zone           object
# dtypes: datetime64[us](3), float32(9), float64(4), geometry(1), int32(4), object(6)
# memory usage: 1.7+ GB

# %%
map_data.describe()
# Out:
#            VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  1.034979e+07                    10349789                    10349789
# mean   1.781919e+00  2024-11-15 04:43:29.318684  2024-11-15 05:00:50.907635
# min    1.000000e+00         2002-12-31 22:17:43         2002-12-31 22:23:55
# 25%    2.000000e+00         2024-10-23 23:34:21         2024-10-23 23:49:55
# 50%    2.000000e+00         2024-11-15 07:22:39         2024-11-15 07:38:00
# 75%    2.000000e+00         2024-12-07 19:24:36         2024-12-07 19:44:35
# max    6.000000e+00         2025-03-23 20:42:06         2025-03-23 22:52:56
# std    4.137425e-01                         NaN                         NaN
#
#        passenger_count  trip_distance    RatecodeID  PULocationID  \
# count     1.034979e+07   1.034979e+07  1.034979e+07  1.034979e+07
# mean      1.314176e+00   3.283729e+00  1.053325e+00  1.652579e+02
# min       1.000000e+00   1.000000e-02  1.000000e+00  1.000000e+00
# 25%       1.000000e+00   1.030000e+00  1.000000e+00  1.320000e+02
# 50%       1.000000e+00   1.740000e+00  1.000000e+00  1.620000e+02
# 75%       1.000000e+00   3.290000e+00  1.000000e+00  2.340000e+02
# max       6.000000e+00   9.690000e+01  6.000000e+00  2.630000e+02
# std       7.264732e-01   4.101263e+00  3.092175e-01  6.392910e+01
#
#        DOLocationID   fare_amount    tip_amount  tolls_amount  \
# count  1.034979e+07  1.034979e+07  1.034979e+07  1.034979e+07
# mean   1.637752e+02  1.969823e+01  3.502190e+00  5.503738e-01
# min    1.000000e+00  2.510000e+00  0.000000e+00  0.000000e+00
# 25%    1.140000e+02  9.300000e+00  7.000000e-01  0.000000e+00
# 50%    1.620000e+02  1.420000e+01  2.800000e+00  0.000000e+00
# 75%    2.340000e+02  2.260000e+01  4.480000e+00  0.000000e+00
# max    2.630000e+02  2.500000e+02  5.725000e+02  1.500000e+02
# std    6.905821e+01  1.615117e+01  3.991741e+00  2.023685e+00
#
#        congestion_surcharge   Airport_fee                        date  \
# count          1.034979e+07  1.034979e+07                    10349789
# mean           2.379901e+00  1.309313e-01  2024-11-14 13:49:14.199701
# min            0.000000e+00  0.000000e+00         2002-12-31 00:00:00
# 25%            2.500000e+00  0.000000e+00         2024-10-23 00:00:00
# 50%            2.500000e+00  0.000000e+00         2024-11-15 00:00:00
# 75%            2.500000e+00  0.000000e+00         2024-12-07 00:00:00
# max            2.500000e+00  1.750000e+00         2025-03-23 00:00:00
# std            6.440200e-01  4.478409e-01                         NaN
#
#                time      duration      OBJECTID    Shape_Leng    Shape_Area  \
# count  1.034979e+07  1.034979e+07  1.034979e+07  1.034979e+07  1.034979e+07
# mean   1.440315e+01  1.735981e+01  1.652580e+02  5.529872e-02  2.045087e-04
# min    0.000000e+00  1.016667e+00  1.000000e+00  1.927050e-02  1.802598e-05
# 25%    1.100000e+01  8.266666e+00  1.320000e+02  3.580391e-02  6.072357e-05
# 50%    1.500000e+01  1.365000e+01  1.620000e+02  4.221260e-02  9.425384e-05
# 75%    1.900000e+01  2.201667e+01  2.340000e+02  5.028132e-02  1.288489e-04
# max    2.300000e+01  1.799000e+02  2.630000e+02  4.334697e-01  4.866340e-03
# std    5.838452e+00  1.344569e+01  6.392896e+01  4.528308e-02  4.087329e-04
#
#          LocationID
# count  1.034979e+07
# mean   1.652579e+02
# min    1.000000e+00
# 25%    1.320000e+02
# 50%    1.620000e+02
# 75%    2.340000e+02
# max    2.630000e+02
# std    6.392910e+01

# %%
map_data
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2024-10-01 00:30:44   2024-10-01 00:48:26
# 1                1  2024-10-01 00:12:20   2024-10-01 00:25:25
# 2                1  2024-10-01 00:04:46   2024-10-01 00:13:52
# 3                1  2024-10-01 00:12:10   2024-10-01 00:23:01
# 4                2  2024-10-01 00:31:20   2024-10-01 00:36:00
# ...            ...                  ...                   ...
# 10349847         1  2024-12-31 23:42:33   2024-12-31 23:53:54
# 10349848         1  2024-12-31 23:21:36   2024-12-31 23:32:10
# 10349849         1  2024-12-31 23:14:53   2024-12-31 23:35:13
# 10349850         2  2024-12-31 23:03:16   2024-12-31 23:28:35
# 10349851         1  2024-12-31 23:15:33   2024-12-31 23:36:29
#
#           passenger_count  trip_distance  RatecodeID  PULocationID  \
# 0                     1.0           3.00         1.0           162
# 1                     1.0           2.20         1.0            48
# 2                     1.0           2.70         1.0           142
# 3                     1.0           3.10         1.0           233
# 4                     2.0           0.97         1.0           137
# ...                   ...            ...         ...           ...
# 10349847              1.0           1.70         1.0            61
# 10349848              1.0           1.60         1.0           188
# 10349849              1.0           2.90         1.0           145
# 10349850              1.0           3.94         1.0           181
# 10349851              1.0           4.20         1.0           165
#
#           DOLocationID  fare_amount  tip_amount  ...  OBJECTID  Shape_Leng  \
# 0                  246    18.400000        1.50  ...     162.0    0.035270
# 1                  236    14.200000        3.80  ...      48.0    0.043747
# 2                   24    13.500000        3.70  ...     142.0    0.038176
# 3                   75    14.200000        2.00  ...     233.0    0.048036
# 4                  137     7.200000        2.44  ...     137.0    0.046108
# ...                ...          ...         ...  ...       ...         ...
# 10349847            71    11.400000        0.00  ...      61.0    0.117311
# 10349848            61    13.280000        0.00  ...     188.0    0.097798
# 10349849           164    21.940001        0.00  ...     145.0    0.114314
# 10349850           255     4.460000        5.19  ...     181.0    0.089537
# 10349851            61    27.070000        0.00  ...     165.0    0.088608
#
#           Shape_Area                            zone  LocationID    borough  \
# 0           0.000048                    Midtown East       162.0  Manhattan
# 1           0.000094                    Clinton East        48.0  Manhattan
# 2           0.000076             Lincoln Square East       142.0  Manhattan
# 3           0.000116             UN/Turtle Bay South       233.0  Manhattan
# 4           0.000116                        Kips Bay       137.0  Manhattan
# ...              ...                             ...         ...        ...
# 10349847    0.000511             Crown Heights North        61.0   Brooklyn
# 10349848    0.000313       Prospect-Lefferts Gardens       188.0   Brooklyn
# 10349849    0.000347  Long Island City/Hunters Point       145.0     Queens
# 10349850    0.000307                      Park Slope       181.0   Brooklyn
# 10349851    0.000354                         Midwood       165.0   Brooklyn
#
#                                                    geometry    Borough  \
# 0         POLYGON ((992224.354 214415.293, 992096.999 21...  Manhattan
# 1         POLYGON ((986694.313 214463.846, 986568.184 21...  Manhattan
# 2         POLYGON ((989380.305 218980.247, 989359.803 21...  Manhattan
# 3         MULTIPOLYGON (((993816.792 213230.43, 993857.4...  Manhattan
# 4         POLYGON ((991954.728 209026.462, 991949.076 20...  Manhattan
# ...                                                     ...        ...
# 10349847  POLYGON ((1003897.089 188278.65, 1003939.593 1...   Brooklyn
# 10349848  POLYGON ((996098.526 181302.644, 996121.518 18...   Brooklyn
# 10349849  POLYGON ((999916.846 213275.139, 1000066.513 2...     Queens
# 10349850  POLYGON ((990954.947 181851.707, 990815.59 181...   Brooklyn
# 10349851  POLYGON ((995312.051 168409.655, 995365.558 16...   Brooklyn
#
#                                     Zone  service_zone
# 0                           Midtown East   Yellow Zone
# 1                           Clinton East   Yellow Zone
# 2                    Lincoln Square East   Yellow Zone
# 3                    UN/Turtle Bay South   Yellow Zone
# 4                               Kips Bay   Yellow Zone
# ...                                  ...           ...
# 10349847             Crown Heights North     Boro Zone
# 10349848       Prospect-Lefferts Gardens     Boro Zone
# 10349849  Long Island City/Hunters Point     Boro Zone
# 10349850                      Park Slope     Boro Zone
# 10349851                         Midwood     Boro Zone
#
# [10349789 rows x 27 columns]

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ##กราฟแสดงการใช้บริการในแต่ละประเภทการคำนวนค่าโดยสาร

# %%
# Mapping RatecodeID to RatecodeName
ratecode_mapping = {
    1.0: 'Standard rate',
    2.0: 'JFK',
    3.0: 'Newark',
    4.0: 'Nassau/Westchester',
    5.0: 'Negotiated fare',
    6.0: 'Group ride',
    99.0: 'Unknown'
}

# Count trips for each Ratecode and Map Names
ratecode_counts_with_names = map_data['RatecodeID'].value_counts().rename(index=ratecode_mapping)

# Plot the graph
plt.figure(figsize=(10, 8))
ax = ratecode_counts_with_names.plot(
    kind='bar',
    color='#F5AD18',
    title='Ratecode Distribution (Counts)',
    ylabel='Number of Trips'
)

plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Add trip counts on top of bars
for p in ax.patches:
    ax.annotate(f'{p.get_height():,}',
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center',
                va='bottom',
                xytext=(0, 5),
                textcoords='offset points')

# Format Y-axis as integers with commas
ax.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

plt.show()

# %% [markdown]
# สรุป Standard rate(มิเตอร์ปกติ) มีจำนวนการใช้บริการมากที่สุด

# %% [markdown]
# ##กราฟแสดงจำนวนประเภทการคำนวนค่าโดยสารในช่วงเวลาการใช้บริการ

# %%
# 1️⃣ แปลงเวลารับผู้โดยสารเป็นชั่วโมง
map_data['pickup_hour'] = map_data['time']

# 2️⃣ คำนวณจำนวนทริปของแต่ละ Ratecode ต่อชั่วโมง
hourly_counts = (
    map_data.groupby(['pickup_hour', 'RatecodeID'])
    .size()
    .reset_index(name='trip_count')
)

# 3️⃣ แปลงให้เป็นสัดส่วน (%) ต่อชั่วโมง
hourly_counts['share_%'] = (
    hourly_counts.groupby('pickup_hour')['trip_count']
    .transform(lambda x: (x / x.sum()) * 100)
).round(2)

# Map RatecodeID to RatecodeName
hourly_counts['RatecodeName'] = hourly_counts['RatecodeID'].map(ratecode_mapping)

# 4️⃣ วาดกราฟเส้น แยกแต่ละประเภท Ratecode
plt.figure(figsize=(10,6))
for rate in hourly_counts['RatecodeID'].unique():
    sub = hourly_counts[hourly_counts['RatecodeID'] == rate]
    plt.plot(sub['pickup_hour'], sub['share_%'], marker='o', label=ratecode_mapping.get(rate, 'Unknown'))

plt.title('Ratecode Distribution by Hour of Day')
plt.xlabel('Hour of Day (0–23)')
plt.ylabel('% of Trips')
plt.legend(title='Ratecode Type', bbox_to_anchor=(1.05,1), loc='upper left')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2236685068.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   map_data['pickup_hour'] = map_data['time']

# %% [markdown]
# สรุป ในช่วงเวลา 5 AM. การคำนวนค่าโดยสารแบบ Standard rate ลดลง แต่ JFK เพิ่มสูงขึ้น

# %% [markdown]
# ##กราฟแสดงการแจกแจงของระยะการเดินทาง

# %%
# เลือกข้อมูล
data = map_data['trip_distance']

# ตัด outlier 1% ขึ้นไปเพื่อให้กราฟไม่บีบแน่น
upper_limit = data.quantile(0.99)
data_clipped = data[data <= upper_limit]

plt.figure(figsize=(10, 6))

# วาด histogram + KDE
sns.histplot(
    data_clipped,
    bins=50,
    color='#9B5DE0',
    edgecolor='black',
    kde=True
)

# แสดง median
median_val = data_clipped.median()
plt.axvline(median_val, color='red', linestyle='--', label=f'Median = {median_val:.2f} miles')

# ชื่อกราฟและแกน
plt.title('Histogram of Trip Distance', fontsize=16)
plt.xlabel('Trip Distance (miles)', fontsize=12)
plt.ylabel('Number of Trips', fontsize=12)

# legend
plt.legend()

# tight layout
plt.tight_layout()
plt.show()

# %% [markdown]
# พบว่า ช่วงของระยะทางที่ใช้บริการอยู่ที่ 0.0 - 5.0 miles

# %% [markdown]
# ## Top 20 Zone ที่มีการรับผู้โดยสารสูงสุด

# %%
# นับจำนวนครั้งที่แต่ละ PULocationID ปรากฏ
pulocation_counts = map_data['PULocationID'].value_counts().reset_index()
pulocation_counts.columns = ['PULocationID', 'Count']

# เลือกเฉพาะ LocationID ที่มีความถี่สูงสุด 20 อันดับแรก
top_pulocations = pulocation_counts.head(20)

# Merge with zone_location to get the zone names
top_pulocations = top_pulocations.merge(zone_location[['LocationID', 'Zone']], left_on='PULocationID', right_on='LocationID', how='left')

# สร้าง labels สำหรับ Treemap (แสดง Zone และจำนวนครั้ง)
labels = top_pulocations.apply(lambda x: f"{x['Zone']} ({x['Count']:,})", axis=1)

# กำหนดขนาดของแต่ละช่องใน Treemap (ตามจำนวน Count)
sizes = top_pulocations['Count'].values

# สร้างสีที่น่าสนใจสำหรับ Treemap โดยใช้ colormap 'viridis'
colors = [cm.viridis(i / float(len(labels))) for i in range(len(labels))]

# วาด Treemap
plt.figure(figsize=(14, 10))
squarify.plot(sizes=sizes, label=labels, color=colors, alpha=.8)

# ตั้งชื่อกราฟ
plt.title('Top 20 Pickup Location Zone Treemap', fontsize=18)

# ปิดแกน x และ y เนื่องจาก Treemap ไม่ได้ใช้แกน
plt.axis('off')
plt.show()

# %% [markdown]
# พบว่า Zone ที่มีการรับผู้โดยสารสูงสุด
#
# 1.   Upper East Side South 531,601 ครั้ง
# 2.   Midtown Center 484,473 ครั้ง
# 3.   Upper East Side North 469,837 ครั้ง

# %% [markdown]
# ## Top 20 Zone ที่มีการส่งผู้โดยสารสูงสุด

# %%
# นับจำนวนครั้งที่แต่ละ DOLocationID ปรากฏ
dolocation_counts = map_data['DOLocationID'].value_counts().reset_index()
dolocation_counts.columns = ['DOLocationID', 'Count']

# เลือกเฉพาะ LocationID ที่มีความถี่สูงสุด 20 อันดับแรก
top_dolocations = dolocation_counts.head(20)

# Merge with zone_location to get the zone names
top_dolocations = top_dolocations.merge(zone_location[['LocationID', 'Zone']], left_on='DOLocationID', right_on='LocationID', how='left')

# สร้าง labels สำหรับ Treemap (แสดง Zone และจำนวนครั้ง)
labels = top_dolocations.apply(lambda x: f"{x['Zone']} ({x['Count']:,})", axis=1)

# กำหนดขนาดของแต่ละช่องใน Treemap (ตามจำนวน Count)
sizes = top_dolocations['Count'].values

# สร้างสีที่น่าสนใจสำหรับ Treemap
colors = [plt.cm.plasma(i/float(len(labels))) for i in range(len(labels))] # ใช้ colormap อื่นเพื่อให้แตกต่างจาก PULocationID

# วาด Treemap
plt.figure(figsize=(14, 10))
squarify.plot(sizes=sizes, label=labels, color=colors, alpha=.8)

# ตั้งชื่อกราฟ
plt.title('Top 20 Dropoff Location Zone Treemap', fontsize=18)

# ปิดแกน x และ y เนื่องจาก Treemap ไม่ได้ใช้แกน
plt.axis('off')
plt.show()

# %% [markdown]
# พบว่า Zone ที่มีการรับผู้โดยสารสูงสุด
#
# 1.   Upper East Side South 488,984 ครั้ง
# 2.   Upper East Side North 473,596 ครั้ง
# 3.   Midtown Center 397,482 ครั้ง

# %% [markdown]
# ##กราฟเส้นแสดงการกระจายของค่าทิป

# %%
# 🔹 สร้างกราฟเส้นแสดงการกระจายของ tip_amount

plt.figure(figsize=(10, 6))

# คำนวณข้อมูล Histogram ก่อน (ความถี่และขอบเขตของ bins)
# density=False หมายถึงนับจำนวน (frequency) ไม่ใช่ความหนาแน่น (density)
counts, bin_edges = np.histogram(map_data['tip_amount'], bins=50)

# คำนวณจุดกึ่งกลางของแต่ละ bin เพื่อใช้เป็นค่าบนแกน X
bin_midpoints = (bin_edges[:-1] + bin_edges[1:]) / 2.0

# วาดกราฟเส้น
plt.plot(bin_midpoints, counts, marker='o', linestyle='-', color='#1A2A4F')

# 🔹 ตั้งชื่อกราฟและแกน
plt.title('Distribution of Tip Amount')
plt.xlabel('Tip Amount ($)')
plt.ylabel('Frequency')

# 🔹 จัด layout ให้อ่านง่าย
plt.tight_layout()
plt.show()
# 🔹 นับความถี่ของ "ค่าทิป" แต่ละค่าที่ปรากฏในข้อมูล
tip_counts = map_data['tip_amount'].value_counts()

# 1. พิมพ์ 20 อันดับแรกที่พบบ่อยที่สุด (Most Frequent)
print("--- Top 20 Most Frequent Tip Amounts ---")
print(tip_counts.head(10))

print("\n" + "-"*40 + "\n")

# 2. พิมพ์ 20 อันดับแรกที่เป็นค่าสูงสุด (Highest Tip Values)
# เรา .sort_index() เพื่อเรียงตาม "ค่าทิป" (จากมากไปน้อย)
print("--- Top 20 Highest Tip Amount Values ---")
print(tip_counts.sort_index(ascending=False).head(10))
# Out:
# --- Top 20 Most Frequent Tip Amounts ---
# tip_amount
# 0.0    2547845
# 2.0     501628
# 1.0     373456
# 3.0     266103
# 5.0     152304
# 2.8     115376
# 4.0     114821
# 3.5     108047
# 2.1      94533
# 1.5      94176
# Name: count, dtype: int64
#
# ----------------------------------------
#
# --- Top 20 Highest Tip Amount Values ---
# tip_amount
# 572.500000    1
# 500.000000    1
# 477.049988    1
# 471.000000    1
# 456.000000    1
# 365.079987    1
# 335.500000    1
# 325.549988    1
# 324.500000    1
# 303.000000    1
# Name: count, dtype: int64

# %% [markdown]
# พบว่า ส่วนใหญ่ไม่มีการให้ทิป และทิปที่สูงสุดคือ 572 $

# %% [markdown]
# ## กราฟแท่งแสดงการกระจายของค่าผ่านทาง

# %%
# เลือกข้อมูล
data = map_data['tolls_amount']

# ตัด outlier 99% เพื่อให้กราฟไม่บีบแน่น
upper_limit = data.quantile(0.99)
data_clipped = data[data <= upper_limit]

plt.figure(figsize=(10, 6))

# วาด histogram + KDE
sns.histplot(
    data_clipped,
    bins=30,
    color='lightgreen',
    edgecolor='black',
    kde=True
)

# แสดง median
median_val = data_clipped.median()
plt.axvline(median_val, color='red', linestyle='--', label=f'Median = ${median_val:.2f}')

# ชื่อกราฟและแกน
plt.title('Histogram of Tolls Amount', fontsize=16)
plt.xlabel('Tolls Amount (USD)', fontsize=12)
plt.ylabel('Number of Trips', fontsize=12)

# legend
plt.legend()

# tight layout
plt.tight_layout()
plt.show()
display(data.value_counts())
# Out:
# tolls_amount
# 0.000000     9586424
# 6.940000      712506
# 15.380000       7138
# 13.380000       6986
# 3.180000        4370
#               ...
# 12.840000          1
# 4.880000           1
# 22.530001          1
# 19.510000          1
# 26.459999          1
# Name: count, Length: 1552, dtype: int64

# %% [markdown]
# พบว่า ส่วนใหญ่ค่าผ่านทางเป็น 0 และรองลงมาคือ 6.94

# %% [markdown]
# ##กราฟแสดงการแจกแจงของค่าธรรมเนียมเพิ่มเติม

# %%
# เลือกข้อมูล
data = map_data['congestion_surcharge']

plt.figure(figsize=(10, 6))

# วาด histogram + KDE
# ใช้สีส้ม (darkorange) ซึ่งอาจสื่อถึง 'การจราจรติดขัด' หรือ 'ค่าธรรมเนียมเพิ่มเติม'
# edgecolor='black' ช่วยให้แท่ง histogram ดูเด่นขึ้น
sns.histplot(
    data,
    bins=30, # ปรับจำนวน bins ตามความเหมาะสม
    color='darkorange',
    edgecolor='black',
    kde=True # เพิ่ม KDE curve
)

# แสดง median (ค่ากลาง) - อาจจะไม่สื่อความหมายมากนักหากมีค่าซ้ำๆ เยอะ
median_val = data.median()
plt.axvline(median_val, color='red', linestyle='--', label=f'Median = ${median_val:.2f}')

# ชื่อกราฟและแกน
plt.title('Distribution of Congestion Surcharge', fontsize=16)
plt.xlabel('Congestion Surcharge (USD)', fontsize=12)
plt.ylabel('Number of Trips', fontsize=12)

# เพิ่ม legend สำหรับเส้น median
plt.legend()

# จัด layout
plt.tight_layout()
plt.show()

# อาจจะดูค่าที่พบบ่อยที่สุดด้วย เนื่องจากเป็นค่าคงที่
print("\nValue Counts for Congestion Surcharge:")
display(data.value_counts())
# Out:
# Value Counts for Congestion Surcharge:
# congestion_surcharge
# 2.50    9852589
# 0.00     497189
# 1.00          8
# 0.75          3
# Name: count, dtype: int64

# %% [markdown]
# พบว่า ค่าธรรมเนียมเพิ่มเติม ส่วนใหญ่อยู่ที่ 2.50

# %% [markdown]
# ##กราฟแสดงการแจกแจงของค่าธรรมเนียมสนามบิน

# %%
# เลือกข้อมูล
data = map_data['Airport_fee']

plt.figure(figsize=(10, 6))

# วาด histogram + KDE
# ใช้สีม่วง (purple) ซึ่งอาจสื่อถึงการเดินทางหรือสนามบิน
# edgecolor='black' ช่วยให้แท่ง histogram ดูเด่นขึ้น
sns.histplot(
    data,
    bins=30, # ปรับจำนวน bins ตามความเหมาะสม
    color='purple',
    edgecolor='black',
    kde=True # เพิ่ม KDE curve
)

# แสดง median (ค่ากลาง) - อาจจะไม่สื่อความหมายมากนักหากมีค่าซ้ำๆ เยอะ
median_val = data.median()
plt.axvline(median_val, color='red', linestyle='--', label=f'Median = ${median_val:.2f}')

# ชื่อกราฟและแกน
plt.title('Distribution of Airport Fee', fontsize=16)
plt.xlabel('Airport Fee (USD)', fontsize=12)
plt.ylabel('Number of Trips', fontsize=12)

# เพิ่ม legend สำหรับเส้น median
plt.legend()

# จัด layout
plt.tight_layout()
plt.show()

# อาจจะดูค่าที่พบบ่อยที่สุดด้วย เนื่องจากอาจมีค่าคงที่
print("\nValue Counts for Airport Fee:")
display(data.value_counts())
# Out:
# Value Counts for Airport Fee:
# Airport_fee
# 0.00    9575439
# 1.75     774348
# 1.25          2
# Name: count, dtype: int64

# %% [markdown]
# พบว่า ส่วนใหญ่ค่าธรรมเนียมสนามบิน เป็น 0 รองลงมาเป็น 1.75

# %% [markdown]
# ##กราฟแสดงการแจกแจงของระยะเวลาระหว่างการเดินทาง

# %%
# เลือกข้อมูล
data = map_data['duration']

plt.figure(figsize=(10, 6))

# วาด histogram + KDE
# ใช้สีเขียว (forestgreen) ซึ่งอาจสื่อถึง 'เวลาที่ผ่านไป' หรือ 'ระยะเวลา'
# edgecolor='black' ช่วยให้แท่ง histogram ดูเด่นขึ้น
sns.histplot(
    data,
    bins=50, # ปรับจำนวน bins ตามความเหมาะสม
    color='forestgreen',
    edgecolor='black',
    kde=True # เพิ่ม KDE curve
)

# แสดง median (ค่ากลาง)
median_val = data.median()
plt.axvline(median_val, color='red', linestyle='--', label=f'Median = {median_val:.2f} minutes')

# ชื่อกราฟและแกน
plt.title('Distribution of Trip Duration', fontsize=16)
plt.xlabel('Duration (minutes)', fontsize=12)
plt.ylabel('Number of Trips', fontsize=12)

# เพิ่ม legend สำหรับเส้น median
plt.legend()

# จัด layout
plt.tight_layout()
plt.show()
display(data.value_counts())
# Out:
# duration
# 9.000000      11793
# 10.000000     11695
# 11.000000     11451
# 8.000000      11303
# 7.000000      11150
#               ...
# 118.766670        1
# 116.783333        1
# 143.199997        1
# 163.183334        1
# 123.533333        1
# Name: count, Length: 8368, dtype: int64

# %% [markdown]
# พบว่า ระยะเวลาระหว่างการเดินทางอยู่ในช่วง 0 - 75 นาที

# %% [markdown]
# ##กราฟแสดงค่าเฉลี่ยระยะทางในแต่ละช่วงเวลา

# %%
# Calculate the average trip distance for each hour of the day
average_distance_by_hour = taxi_data.groupby('time')['trip_distance'].mean().reset_index()

# Create a line plot
plt.figure(figsize=(12, 6))
plt.plot(average_distance_by_hour['time'], average_distance_by_hour['trip_distance'], marker='o', linestyle='-')

plt.title('Average Trip Distance by Hour of Day')
plt.xlabel('Hour of Day (0-23)')
plt.ylabel('Average Trip Distance (miles)')
plt.xticks(range(0, 24)) # Ensure all hours are shown on the x-axis
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# พบว่า ในช่วงเวลา 4 AM. - 6 AM. การเดินทางมีระยะทางไกล และช่วงเวลาที่การเดินทางมีระยะทางไกลที่สุดคือ 5 AM.

# %% [markdown]
# ##กราฟแสดงค่าเฉลี่ยค่าธรรมเนียมเพิ่มเติมในแต่ละช่วงเวลา

# %%
# Calculate the average congestion surcharge for each hour of the day
average_congestion_by_hour = map_data.groupby('time')['congestion_surcharge'].mean().reset_index()

# Create a line plot
plt.figure(figsize=(12, 6))
plt.plot(average_congestion_by_hour['time'], average_congestion_by_hour['congestion_surcharge'], marker='o', linestyle='-')

plt.title('Average Congestion Surcharge by Hour of Day')
plt.xlabel('Hour of Day (0-23)')
plt.ylabel('Average Congestion Surcharge (USD)')
plt.xticks(range(0, 24)) # Ensure all hours are shown on the x-axis
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# พบว่า ในช่วงเวลา 4 AM. - 6 AM. ค่าเฉลี่ยค่าธรรมเนียมเพิ่มเติมต่ำ และช่วงเวลาที่ค่าเฉลี่ยค่าธรรมเนียมเพิ่มเติมต่ำสุดคือ 5 AM.

# %% [markdown]
# ##กราฟแสดงค่าเฉลี่ยระยะทางในแต่ละโซนให้บริการ

# %%
# Calculate the average trip distance for each service zone
average_distance_by_service_zone = map_data.groupby('service_zone')['trip_distance'].mean().reset_index()

# Reshape the data for the heatmap
heatmap_data_service_zone = average_distance_by_service_zone.set_index('service_zone').T

# Create the heatmap
plt.figure(figsize=(10, 4))
sns.heatmap(heatmap_data_service_zone, annot=True, fmt=".2f", cmap="YlGnBu", cbar_kws={'label': 'Average Trip Distance (miles)'})

plt.title('Average Trip Distance by Service Zone Heatmap')
plt.xlabel('Service Zone')
plt.ylabel('Metric')
plt.yticks(rotation=0)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# พบว่า ค่าเฉลี่ยระยะทางในแต่ละโซนให้บริการ(miles)
#
# 1.   Airports 13.32
# 2.   EWR 8.31
# 3.  Boro Zone 4.69
# 4. Yellow Zone 2.36

# %% [markdown]
# ##กราฟแสดงค่าเฉลี่ยทิปในแต่ละโซนให้บริการ

# %%
# Calculate the average tip amount for each service zone
average_tip_by_service_zone = map_data.groupby('service_zone')['tip_amount'].mean().reset_index()

# Sort the data by average tip amount in descending order
average_tip_by_service_zone = average_tip_by_service_zone.sort_values(by='tip_amount', ascending=False)

# Create a bar plot
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='service_zone', y='tip_amount', data=average_tip_by_service_zone, palette='viridis')

plt.title('Average Tip Amount by Service Zone')
plt.xlabel('Service Zone')
plt.ylabel('Average Tip Amount (USD)')
plt.xticks(rotation=45, ha='right')

# Add the average tip amount on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}',
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center',
                va='bottom',
                xytext=(0, 5), # Offset text slightly above the bar
                textcoords='offset points')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2651325516.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='service_zone', y='tip_amount', data=average_tip_by_service_zone, palette='viridis')

# %% [markdown]
# พบว่า ค่าเฉลี่ยทิปในแต่ละโซนให้บริการ(USD)
#
#
# 1.  EWR 12.70
# 2.  Airports 9.59
# 3. Yellow Zone 3.03
# 4. Boro Zone 2.55
